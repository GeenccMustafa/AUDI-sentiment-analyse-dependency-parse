# %%
import numpy as np
import pandas as pd
import os
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import spacy
from spacy.language import Language

#ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#load datasets
english = pd.read_csv("english.csv")

# %%
nlp_eng = spacy.load("en_core_web_sm")

# %% [markdown]
# # Getting the dependency parse

# %%
def find_root_of_sentence(text):
    doc = nlp_eng(text)
    root_token = None
    for token in doc:
        if (token.dep_ == "ROOT"):
            root_token = token
    return root_token

# %%
all_root_tokens = english["lemma_eng_review"].apply(lambda x: find_root_of_sentence(x)) 
all_roots = all_root_tokens.apply(lambda x: x.text if len(x.text) >= 2 else None) #text means add str type instead token type

# %%
roots_df = all_roots.to_frame()
roots_df.rename(columns={"lemma_eng_review":"Root"}, inplace=True)
roots = roots_df["Root"].value_counts().sort_values(ascending=False).head(30)
roots = pd.DataFrame(roots).rename_axis("Root")
roots.columns = roots.columns.str.replace('Root', 'Count')
roots.reset_index(inplace=True)
roots
# Out:
#           Root  Count
# 0           be   1377
# 1      service    330
# 2        thank    326
# 3         have    318
# 4          buy    301
# 5    recommend    243
# 6       advice    135
# 7           go    111
# 8        staff    102
# 9         like     80
# 10         get     79
# 11        give     68
# 12         say     68
# 13        feel     67
# 14        come     67
# 15     receive     61
# 16        take     57
# 17        want     57
# 18  dealership     56
# 19        find     54
# 20        make     52
# 21         top     48
# 22       think     46
# 23          do     36
# 24        help     36
# 25        keep     35
# 26        look     35
# 27  everything     35
# 28    friendly     33
# 29      advise     33

# %%
import plotly.graph_objects as go
import plotly.io as pio

# %%
fig = go.Figure([go.Bar(x=roots['Root'], y=roots['Count'])])
fig.update_layout(title=go.layout.Title(text="Top 30 Roots in the reviews text after lemmatization"))
pio.renderers.default = 'iframe'
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
def find_other_verbs(doc, root_token):
    other_verbs = []
    for token in doc:
        ancestors = list(token.ancestors)
        if (token.pos_ == "VERB" and len(ancestors) == 1 and ancestors[0] == root_token):
            other_verbs.append(token)
    return other_verbs

# %%
sentences = english["lemma_eng_review"].to_list()
verbs = []
for sentence in sentences:
    doc = nlp_eng(sentence)
    root_token = find_root_of_sentence(doc)
    verbs.append(find_other_verbs(doc, root_token))

# %%
other_verbs = [item.text for sublist in verbs for item in sublist] # run only one time
other_verbs_df = pd.DataFrame(other_verbs, columns=["Verbs"])
verbs = other_verbs_df["Verbs"].sort_values().value_counts().head(30)
verbs = pd.DataFrame(verbs).reset_index()
verbs.columns = verbs.columns.str.replace('Verbs', 'Count')
verbs.columns = verbs.columns.str.replace('index', 'Verbs')
verbs = verbs[verbs["Verbs"].str.len() >= 2]
verbs
# Out:
#         Verbs  Count
# 0          be    718
# 1        have    397
# 2       thank    309
# 3         buy    261
# 4   recommend    218
# 5          go    195
# 6        take    152
# 7         get    149
# 8        look    125
# 9        make    122
# 10       come    106
# 11       give    105
# 12       feel    100
# 13         do     84
# 14       keep     83
# 15       find     79
# 16        say     71
# 17       want     71
# 18       like     67
# 19    receive     54
# 20      drive     52
# 21       pick     50
# 22     answer     50
# 23       work     48
# 25       wait     48
# 26       call     48
# 27        ask     47
# 28        see     45
# 29       know     44

# %%
fig = go.Figure([go.Bar(x=verbs['Verbs'], y=verbs['Count'])])
fig.update_layout(title=go.layout.Title(text="Top 30 Verbs in the reviews text after lemmatization"))
pio.renderers.default = 'iframe'
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_22.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
def get_parse(sentence):
    doc = nlp_eng(sentence)
    adverb_list = []
    adjective_list = []
    noun_list = []
    conjunction_list = []
    for token in doc:
        word = token.text
        pos = token.pos_
        if pos == "ADV":
            adv_word = word
            adverb_list.append(adv_word)
        elif pos == "ADJ":
            adj_word = word
            adjective_list.append(adj_word)
        elif pos == "NOUN":
            noun = word
            noun_list.append(noun)
        elif pos == "CONJ" or pos == "CCONJ":  # coordinating conjunction
            conjunction = word
            conjunction_list.append(conjunction)
    return adverb_list, adjective_list, noun_list, conjunction_list

# %%
sentences = english["lemma_eng_review"].to_list()
adv_list = []
adj_list = []
noun_list = []
conj_list = []
for sentence in sentences:
    adverbs, adjectives, nouns, conjunctions = get_parse(sentence)
    adv_list.append(adverbs)
    adj_list.append(adjectives)
    noun_list.append(nouns)
    conj_list.append(conjunctions)

# %%
#creata a list from nested lists for adverb and adjectives
adjectives =[item for sublist in adj_list for item in sublist] 
adverbs = [item for sublist in adv_list for item in sublist]
nouns = [item for sublist in noun_list for item in sublist]
conjunctions = [item for sublist in conj_list for item in sublist]

# %%
import collections
adjective_freq = dict(collections.Counter(adjectives))
adverb_freq = dict(collections.Counter(adverbs))
nouns_freq = dict(collections.Counter(nouns))
conjunctions_freq = dict(collections.Counter(conjunctions))

# %%
sorted_adjectives = {k: v for k, v in sorted(adjective_freq.items(), key=lambda item: item[1], reverse=True)}
sorted_adverbs = {k: v for k, v in sorted(adverb_freq.items(), key=lambda item: item[1], reverse=True)}
sorted_nouns = {k: v for k, v in sorted(nouns_freq.items(), key=lambda item: item[1], reverse=True)}
sorted_conjunctions = {k: v for k, v in sorted(conjunctions_freq.items(), key=lambda item: item[1], reverse=True)}

# %%
#get first 30 items from dictionary to visualize most frequents
sorted_adjectives = list(sorted_adjectives.items())
adjectives = dict(sorted_adjectives[:30])

sorted_adverbs = list(sorted_adverbs.items())
adverbs = dict(sorted_adverbs[:30])

sorted_nouns = list(sorted_nouns.items())
nouns = dict(sorted_nouns[:30])

sorted_conjunctions = list(sorted_conjunctions.items())
conjunctions = dict(sorted_conjunctions[:7])

# %%
adverbs_df = pd.DataFrame({"Adverb":adverbs.keys(), "Frequency":adverbs.values()})
adjective_df = pd.DataFrame({"Adjective":adjectives.keys(), "Frequency":adjectives.values()})
nouns_df = pd.DataFrame({"Noun":nouns.keys(), "Frequency":nouns.values()})
conjunctions_df = pd.DataFrame({"Conjunction":conjunctions.keys(), "Frequency":conjunctions.values()})

# %%
fig = go.Figure([go.Bar(x=adverbs_df['Adverb'], y=adverbs_df['Frequency'])])
fig.update_layout(title=go.layout.Title(text="Top 30 Adverbs in the reviews text after lemmatization"))
pio.renderers.default = 'iframe'
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = go.Figure([go.Bar(x=adjective_df['Adjective'], y=adjective_df['Frequency'])])
fig.update_layout(title=go.layout.Title(text="Top 30 Adjective in the reviews text after lemmatization"))
pio.renderers.default = 'iframe'
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_31.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = go.Figure([go.Bar(x=nouns_df['Noun'], y=nouns_df['Frequency'])])
fig.update_layout(title=go.layout.Title(text="Top 30 Nouns in the reviews text after lemmatization"))
pio.renderers.default = 'iframe'
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_32.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = go.Figure([go.Bar(x=conjunctions_df['Conjunction'], y=conjunctions_df['Frequency'])])
fig.update_layout(title=go.layout.Title(text="Top 7 Conjunctions in the reviews text after lemmatization"))
pio.renderers.default = 'iframe'
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_33.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# the tokens which "service" depend on
def dependency(text):
    doc = nlp_eng(text)
    for token in doc:
        if token.text == "service":
            print(token.text)
            ancestors = [t.text for t in token.ancestors]
            print(ancestors)

# %%
english["lemma_eng_review"].apply(lambda x: dependency(x))
# Out:
# service
# ['get']
# service
# ['appointment', 'get']
# service
# ['on', 'appointment', 'get']
# service
# ['employee']
# service
# ['look']
# service
# ['desk', 'at', 'lady', 'be', 'find']
# service
# []
# service
# []
# service
# ['staff']
# service
# []
# service
# ['have', 'have']
# service
# []
# service
# ['advisor', 'be', 'know']
# service
# ['advisor', 'distinguish', 'detail', 'know']
# service
# ['anything', 'about', 'worry', 'have', 'keep', 'know']
# service
# ['be', 'stepsince', 'inform', 'vehicle', 'pick', 'call', 'selfevidentfrom', 'fact', 'worry', 'have', 'keep', 'know']
# service
# ['advisor', 'up', 'pick', 'get', 'know']
# service
# ['with', 'satisfied', 'be', 'have', 'include']
# service
# ['be', 'have', 'come', 'have', 'include']
# service
# ['tüv', 'to', 'relate', 'handle', 'be', 'have', 'come', 'have', 'include']
# service
# ['center', 'at', 'experience', 'after', 'thank', 'find']
# service
# ['thank']
# service
# ['be']
# service
# ['advisor', 'pick', 'service', 'be']
# service
# ['thank']
# service
# ['scheduling', 'by', 'reach', 'easy', 'be', 'thank']
# service
# ['be']
# service
# ['machine', 'to', 'go', 'be', 'merchant', 'to', 'hand', 'be', 'service', 'be']
# service
# ['advisor', 'come', 'estimate']
# service
# ['work', 'be', 'estimate']
# service
# ['pickup', 'with', 'change', 'be', 'estimate']
# service
# []
# service
# ['call', 's', 'look', 'receive', 'call', 'be']
# service
# ['for', 'thank', 'call', 'be']
# service
# ['of', 'term', 'in', 'increase', 'care']
# service
# ['from', 'buy', 'time', 'at', 'be', 'star', 'give']
# service
# ['commensurate', 'expect', 'mention', 'carry']
# service
# ['change', 'to', 'go']
# service
# ['laundry', 'free', 'include', 'go']
# service
# []
# service
# ['service']
# service
# ['thank']
# service
# ['thank', 'be']
# service
# ['recommend']
# service
# ['for', 'recommend']
# service
# ['to', 'bring', 'be', 'be', 'say']
# service
# ['employee', 'say']
# service
# ['euro', 'say']
# service
# ['contract', 'one', 'pay']
# service
# ['be', 'receive']
# service
# ['advisor', 'as', 'go', 'have', 'lucky', 'be', 'be']
# service
# ['care', 'm', 'buy']
# service
# ['advice', 'experience', 'able', 'be']
# service
# ['appointment', 'go', 'update']
# service
# ['appointment', 'be', 'assume', 'be', 'update']
# service
# ['appointment', 'arrange', 'go', 'be', 'assume', 'be', 'update']
# service
# ['appointment', 'have', 'include', 'be', 'be', 'have', 'appointment', 'of', 'day', 'on', 'reserve', 'be', 'find', 'be', 'be', 'update']
# service
# ['tow', 'repair', 'be', 'failure', 'suffer', 'move']
# service
# ['with', 'take', 'deliver', 'suffer', 'move']
# service
# ['therehad', 'give', 'be']
# service
# ['be']
# service
# ['advisor', 'franz', 'florian', 'be']
# service
# ['thank', 'from', 'help', 'thank']
# service
# ['for', 'thank']
# service
# ['for', 'thank', 'make']
# service
# ['serve']
# service
# ['for', 'thank', 'pick', 'able', 'be', 'day', 'organize', 'ask', 'stay']
# service
# ['be']
# service
# ['advisor', 'swachina', 'from', 'advice', 'be', 'be']
# service
# []
# service
# ['advisor', 'despite', 'replace', 'have', 'say', 'glue', 'want', 'be']
# service
# ['advisor', 'audizentrum', 'to', 'comesbrought', 'be']
# service
# ['friendliness', 'of', 'term', 'in', 'be', 'say', 'comesbrought', 'be']
# service
# ['processing', 'for', 'thank', 'have']
# service
# ['as', 'soon', 'get', 'sure', 'make']
# service
# ['car', 'on', 'be']
# service
# ['carry', 'make', 'flexible']
# service
# ['team', 'carry']
# service
# ['visit', 'with', 'as', 'team', 'carry']
# service
# ['employee', 'to', 'thank', 'be']
# service
# []
# service
# ['give']
# service
# ['adviser', 'recommend', 'be', 'make']
# service
# ['answer', 'clarify', 'be', 'look', 'keep']
# service
# ['beyond', 'concern', 'after', 'look', 'reach', 'easy', 'be', 'recommend']
# service
# ['to', 'appointment', 'because', 'be']
# service
# ['appointment', 'for', 'be']
# service
# ['take', 'pick', 'wait', 'question', 'be', 'need', 'wear', 'say']
# service
# ['be']
# service
# ['consultant', 'of', 'one', 'swatschina', 'notice']
# service
# ['value', 'anyone', 'to', 'recommend', 'get', 'notice']
# service
# ['manager', 'with', 'audi', 'appointment', 'have']
# service
# ['keep', 'look', 'save']
# service
# ['in', 'advice', 'receive']
# service
# ['from', 'guy', 'recommend', 'receive']
# service
# ['employee', 'competent', 'know', 'auditorium', 'go']
# service
# ['for', 'thank', 'be', 'have']
# service
# ['tire', 'change', 'to', 'loyal', 'remain', 'buy']
# service
# ['be', 'accept', 'buy']
# service
# ['village', 'skirmish', 'be', 'accept', 'buy']
# service
# ['consultant', 'to', 'care', 'feel', 'be']
# service
# ['with', 'dealership', 'in', 'experience', 'be', 'advice', 'atmosphere', 'be']
# service
# ['manager', 'for', 'wait', 'long', 'hochstraße']
# service
# ['maintenance', 'work', 'show', 'be']
# service
# ['be']
# service
# ['use', 'happy', 'be', 'be', 'be']
# service
# ['consultant', 'minkus', 'leave', 'advise']
# service
# ['team', 'from', 'taiger', 'help', 'thank']
# service
# ['thank', 'do', 'be', 'professional', 'be', 'be']
# service
# ['team', 'transaction']
# service
# ['consultant', 'take', 'transaction']
# service
# ['be', 'be', 'be', 'buy', 'be']
# service
# ['advisor', 'lady', 'helpful', 'be', 'be', 'be', 'buy', 'be']
# service
# ['with', 'displeasure', 'announce', 'resolve']
# service
# ['with', 'workshop', 'be', 'be', 'say']
# service
# ['find', 'tackle', 'of', 'partsinstead', 'of', 'repair', 'during', 'go', 'say']
# service
# ['👌', 'regard', 'advice']
# service
# ['be']
# service
# ['appointment', 'to', 'at', 'm']
# service
# ['contact', 'with', 'consultation', 'be', 'say', 'turn', 'check', 'appear']
# service
# ['be', 'say', 'turn', 'check', 'appear']
# service
# ['be', 'organize', 'say', 'turn', 'check', 'appear']
# service
# ['for', 'look', 'be', 'be']
# service
# ['change', 'for', 'hochstraße', 'to', 'go']
# service
# ['negotiate']
# service
# ['time']
# service
# ['about', 'be', 'disappoint']
# service
# ['be', 'be', 'disappoint']
# service
# ['advisor', 'occur', 'be', 'time', 'at', 'be']
# service
# ['advisor', 'to', 'accord', 'be', 'appointment', 'of', 'beginning', 'at', 'note', 'have', 'be']
# service
# ['accord', 'than', 'more', 'be', 'be']
# service
# ['have', 'inform']
# service
# ['management', 'with', 'conversation', 'have', 'have']
# service
# ['contract', 'recommend']
# service
# ['advisor', 'korndörfer', 'experience', 'be', 'recommend']
# service
# ['advisor', 'contact', 'recommend']
# service
# ['employee', 'startled', 'ask', 'be', 'imagine', 'ask', 'have', 'vacuum']
# service
# ['staff', 'be', 'pick', 'key', 'give', 'ask', 'be', 'imagine', 'ask', 'have', 'vacuum']
# service
# ['be']
# service
# ['acceptance', 'be']
# service
# ['level']
# service
# ['fast']
# service
# ['advisor', 'make', 'have', 'have']
# service
# ['make', 'have', 'have']
# service
# ['nice', 'advice', 'have']
# service
# ['anymoreat', 'recommend']
# service
# ['bring', 'pick', 'service', 'anymoreat', 'recommend']
# service
# ['pickup', 'at', 'one', 'be', 'learn', 'hochstrasse', 'to', 'drive', 'result', 'give', 'tell', 'recommend']
# service
# []
# service
# ['planning']
# service
# ['of', 'planning']
# service
# ['go', 'have']
# service
# ['counter', 'at', 'ask', 'come']
# service
# ['consultant', 'to', 'go', 'thank']
# service
# ['consultant', 'concern', 'be']
# service
# ['consultant', 'be']
# service
# ['inspection', 'due', 'time', 'be', 'come']
# service
# ['despite', 'say', 'time', 'be', 'come']
# service
# ['staff', 'be', 'be']
# service
# ['excellence', 'of', 'trace', 'be', 'describe', 'greet', 'change']
# service
# ['through', 'be', 'change']
# service
# ['reflect']
# service
# ['competent', 'staff', 'processing', 'for', 'deliver']
# service
# ['staff', 'processing', 'for', 'deliver']
# service
# ['advisor', 'give']
# service
# ['to', 'go']
# service
# ['quality', 'be', 'thank', 'pay', 'be']
# service
# ['with', 'unsatisfied', 'receive']
# service
# ['malfunction', 'to', 'hand', 'unsatisfied', 'receive']
# service
# ['in', 'optimization', 'for', 'potential', 'see', 'surprised', 'be', 'buy']
# service
# ['area', 'shine', 'be', 'point']
# service
# ['shine', 'be', 'point']
# service
# ['employee', 'be', 'wait', 'be', 'point']
# service
# ['employee', 'with', 'meet', 'allow', 'mention', 'require', 'be', 'be', 'point']
# service
# ['advisor', 'take', 'allow', 'mention', 'require', 'be', 'be', 'point']
# service
# ['until', 'get', 'estimate', 'request', 'point']
# service
# ['work', 'as', 'long', 'value']
# service
# ['to', 'come', 'stay']
# service
# ['consultant', 'car', 'with', 'stand', 'be', 'have']
# service
# ['of', 'head', 'to', 'talk', 'be', 'be', 'have']
# service
# ['audi', 'for', 'offer', 'get', 'treat', 'lose', 'be', 'have']
# service
# ['in', 'come', 'have']
# service
# ['department', 'via', 'send', 'make', 'go']
# service
# ['intimidation', 'for', 'reminder', 'keep', 'promise', 'watch']
# service
# ['advice', 'order', 'be']
# service
# ['advisor', 'ask', 'pay', 'customer', 'be', 'say']
# service
# ['employee', 'call', 'do', 'be', 'say']
# service
# ['expect', 'be']
# service
# ['atmosphere', 'chapeaui', 'as', 'buy']
# service
# ['management', 'contract', 'recommend', 'for', 'thank']
# service
# ['have', 'decide']
# service
# ['climate', 'for', 'have', 'decide']
# service
# ['consultant', 'of', 'ripoff', 'conclusion', 'decide']
# service
# ['appointment', 'be']
# service
# ['support']
# service
# ['kick', 'be']
# service
# ['thank']
# service
# ['in', 'thank']
# service
# []
# service
# ['change', 'be']
# service
# ['have']
# service
# ['advisor', 'look', 'make']
# service
# ['partner', 'advise']
# service
# ['buy']
# service
# ['advisor', 'thomas', 'schmidt', 'of', 'care', 'from', 'comfortable', 'feel', 'have']
# service
# ['repair']
# service
# ['for', 'water', 'as', 'part', 'be']
# service
# ['dealership', 'be']
# service
# ['receptionist', 'in', 'processing', 'equip']
# service
# ['buchbinder', 'wanninger', 'be']
# service
# ['car', 'handing', 'handle', 'come', 'work', 'give']
# service
# ['thank', 'opportunity', 'take', 'like']
# service
# ['team', 'expandedgreat', 'be']
# service
# ['for', 'thank', 'like']
# service
# ['on', 'service', 'for', 'thank', 'like']
# service
# ['appointment', 'processing']
# service
# ['time', 'thank']
# service
# ['be', 'say', 'have']
# service
# ['thank']
# service
# ['advice', 'thank', 'time', 'be']
# service
# ['be']
# service
# ['consultant', 'desk', 'at', 'be', 'satisfied', 'be']
# service
# ['answer', 'keep']
# service
# ['for', 'ready', 'be']
# service
# ['as', 'be']
# service
# ['address', 'to', 'refer', 'solution', 'be']
# service
# ['because', 'call']
# service
# ['nice']
# service
# ['advice', 'on', 'rely']
# service
# ['from', 'man', 'desk', 'at', 'thank']
# service
# ['repair', 'recommend']
# service
# ['reliable']
# service
# ['processing', 'change']
# service
# ['thank']
# service
# ['thank']
# service
# ['area', 'in', 'lukic', 'from', 'advice', 'thank']
# service
# []
# service
# ['for', 'accept']
# service
# ['friendly', 'staff', 'coffee', 'come']
# service
# []
# service
# ['advice', 'for', 'thank']
# service
# []
# service
# ['praise', 'provide']
# service
# ['be', 'complain']
# service
# []
# service
# ['competent', 'advice']
# service
# []
# service
# ['recommend']
# service
# ['service', 'recommend']
# service
# ['troubleshoot']
# service
# ['against', 'advise']
# service
# ['advice']
# service
# ['friendly', 'staff']
# service
# ['appointment', 'consultant', 'at', 'handling']
# service
# ['consultant', 'at', 'handling']
# service
# ['erkel']
# service
# []
# service
# ['team', 'thank']
# service
# ['situation']
# service
# ['accessibility', 'with', 'dealership']
# service
# []
# service
# ['thank']
# service
# ['for', 'thank']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['appointment']
# service
# []
# service
# ['for', 'thank']
# service
# []
# service
# ['good']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['be', 'experience']
# service
# ['folk', 'for', 'thank', 'service', 'be', 'experience']
# service
# ['guy', 'do', 'assume', 'something', 's', 'be', 'know', 'need', 'be']
# service
# ['come', 'be', 'have', 'call']
# service
# ['advisor', 'communication', 'to', 'connect', 'find', 'call']
# service
# ['shock', 'take']
# service
# ['but', 'nothing', 'have', 'take']
# service
# ['be']
# service
# ['give', 'get']
# service
# ['on', 'back', 'be', 'help', 'give', 'get']
# service
# ['for', 'pay', 'buy', 'be', 'think']
# service
# ['center', 'in', 'return', 'want', 'have', 'have']
# service
# ['center', 'avoid', 'have']
# service
# ['with', 'pleased', 'be']
# service
# ['notification', 'with', 'issue', 'have', 'be']
# service
# ['be', 'have', 'be']
# service
# ['try', 'be']
# service
# ['for', 'be']
# service
# ['because', 'kühler', 'do', 'want']
# service
# ['recall', 'by', 'cause', 'cost', 'cover', 'tell', 'prove', 'tell', 'explain', 'have', 'want']
# service
# ['be', 'cover', 'tell', 'prove', 'tell', 'explain', 'have', 'want']
# service
# ['waste', 'before', 'tell', 'want']
# service
# ['be']
# service
# ['how', 'be', 'recommend', 'be']
# service
# ['assistant', 'be', 'be']
# service
# ['car', 'competent', 'thank']
# service
# ['ok', 'be']
# service
# ['be']
# service
# []
# service
# ['with', 'satisfied']
# service
# []
# service
# ['in', 'answer', 'have']
# service
# ['advisor', 'as', 'wille', 'get', 'be', 'be', 'have']
# service
# ['advisor', 'maria', 'as', 'get', 'stroke', 'work']
# service
# ['in', 'look', 'let', 'discover']
# service
# ['advisor', 'dovecar', 'ibrahimagic', 'by', 'service', 'in', 'look', 'let', 'discover']
# service
# ['advisor', 'be', 'want', 'stay']
# service
# ['employee', 'be', 'orient']
# service
# ['pay', 'understand', 'staff', 'by', 'confirm', 'be', 'orient']
# service
# ['thank']
# service
# ['dealership', 'at', 'marten', 'be']
# service
# ['reischl', 'offer']
# service
# ['proactive', 'offer', 'offer']
# service
# ['help', 'offer', 'offer']
# service
# ['of', 'good', 'be', 'visit']
# service
# ['live']
# service
# ['advisor', 'rousselle', 'from', 'support', 'for', 'thank', 'live']
# service
# ['have']
# service
# ['have', 'have']
# service
# ['before', 'complete', 'be', 'have']
# service
# ['staff', 'by', 'ask', 'disappointing', 'customeroriented', 'find', 'attempt', 'be', 'go']
# service
# ['vehicle', 'about', 'complain', 'little', 'be', 'see']
# service
# ['appointment', 'for', 'time', 'for', 'bring']
# service
# ['employee', 'with', 'see', 'measure', 'bring']
# service
# ['on', 'meet', 'pick', 'able', 'be', 'be', 'bring']
# service
# ['appointment', 'arrange', 'reach']
# service
# ['for', 'back', 'answer', 'reach']
# service
# ['call']
# service
# ['general', 'about', 'be', 'call']
# service
# ['dialing', 'call']
# service
# ['appointment', 'be', 'call']
# service
# ['from', 'answer', 'be', 'see', 'treat', 'way', 's', 'weekend', 'wish', 'stand', 'leave']
# service
# ['desert', 'germany', 'handle', 'leave']
# service
# ['promise', 'from', 'be', 'make', 'have', 'reason', 'for', 'receive']
# service
# ['waitgreat', 'give', 'appointment', 'make', 'to', 'adhere', 'be', 'promise', 'from', 'be', 'make', 'have', 'reason', 'for', 'receive']
# service
# ['staff', 'competent', 'waitgreat', 'give', 'appointment', 'make', 'to', 'adhere', 'be', 'promise', 'from', 'be', 'make', 'have', 'reason', 'for', 'receive']
# service
# ['impeccablei', 'like', 'be']
# service
# ['through', 'say', 'have']
# service
# ['mention', 'have', 'be']
# service
# ['call', 's', 'customer', 'for', 'good', 'be', 'sell', 'take', 'lead', 'have', 'be']
# service
# []
# service
# ['repair', 'whether', 'carry', 'service']
# service
# ['feel']
# service
# ['appointment', 'get']
# service
# ['by', 'pick', 'customer', 'be', 'be']
# service
# ['have', 'show', 'be']
# service
# ['receive', 'vehicle', 'buy', 'have']
# service
# ['employee', 'girl', 'I', 'be']
# service
# ['appointment', 'change']
# service
# ['advisor', 'as', 'change', 'change']
# service
# ['appointment', 'of', 'process', 'arrange', 'try', 'be', 'change']
# service
# ['for', 'have']
# service
# ['employee', 'markus', 'munich', 'peter', 'to', 'thank', 'ask', 'have']
# service
# ['advisor', 'from', 'support', 'for', 'thank']
# service
# ['for', 'thank']
# service
# ['partner', 'for', 'look', 'drive']
# service
# ['ring', 'experience', 'after', 'look', 'drive']
# service
# ['partner', 'find', 'look', 'drive']
# service
# ['call', 's', 'keptye', 'be', 'get']
# service
# ['for', 'make', 'cause', 'be', 'tell', 'call']
# service
# ['for', 'thank', 'want']
# service
# ['on', 'rely', 'know', 'be', 'want']
# service
# ['to', 'bring', 'want', 'understand']
# service
# ['call', 's', 'give']
# service
# ['be', 'thank', 'be']
# service
# ['to', 'go', 'have', 'be']
# service
# ['advice', 'for', 'thank', 'like']
# service
# ['do', 'get', 'go']
# service
# ['staff', 'be', 'go']
# service
# ['carry', 'carry', 'have']
# service
# ['advisor', 'stritzl', 'clarify', 'carry', 'carry', 'have']
# service
# ['for', 'thank', 'like', 'be', 'keep', 'clarify', 'carry', 'carry', 'have']
# service
# ['overdraw', 'bring']
# service
# ['consultant', 'seat', 'on', 'hair', 'be', 'bring']
# service
# ['girl', 'staff', 'to', 'thank', 'partner', 'have', 'happen', 'be']
# service
# ['for', 'thank', 'partner', 'have', 'happen', 'be']
# service
# ['area', 'in', 'helpful', 'friendly', 'be', 'include', 'have']
# service
# ['offer', 'be', 'be', 'praise']
# service
# ['to', 'go', 'find', 'be', 'be']
# service
# ['consultant', 'have', 'lucky', 'be', 'give']
# service
# ['pull']
# service
# ['colleague', 'for', 'wait', 'want', 'cut']
# service
# ['recommend']
# service
# ['advisor', 'sommerfeld', 'with', 'repair', 'processing']
# service
# ['beyond', 'go', 'sommerfeld', 'to', 'go', 'give']
# service
# ['experience', 'for', 'thank']
# service
# ['do', 'do']
# service
# ['for', 'appointment', 'have', 'give', 'do']
# service
# ['consultant', 'find', 'count', 'go', 'give', 'do']
# service
# ['advisor', 'to', 'visit', 'pleasure', 'look']
# service
# ['thank', 'imagine', 's', 'look']
# service
# ['thank', 'recommend']
# service
# ['station', 'be', 'take', 'datum', 'enter', 'have', 'take', 'be']
# service
# ['use', 'want', 'be']
# service
# ['station', 'at', 'expression', 'forget', 'pick']
# service
# ['to', 'relate', 'explain', 'show', 'know', 'pick']
# service
# ['be', 'have']
# service
# ['employee', 'leave', 'be', 'have']
# service
# ['in', 'thing', 'be', 'wait']
# service
# ['center', 'call', 'be', 'wait']
# service
# ['understand']
# service
# ['advisorsall', 'repair', 'lady', 'to', 'smile', 'want', 'ask', 'lady', 'from', 'satisfied', 'be', 'understand']
# service
# ['with', 'center', 'be', 'say', 'have', 'understand']
# service
# ['altenburger', 'be']
# service
# ['advisor', 'reischl', 'take', 'compare', 'be']
# service
# ['staff', 'approach', 'take', 'm', 'review', 'write']
# service
# ['staff', 'think', 'write']
# service
# ['greet', 'make', 'think', 'write']
# service
# ['be']
# service
# ['be', 'change', 'be', 'be']
# service
# ['inspection', 'run']
# service
# ['employee', 'of', 'delay', 'sm', 'be', 'run']
# service
# ['appointment', 'have']
# service
# ['treat', 'advised', 'feel', 'have']
# service
# ['advice', 'be', 'carry', 'have']
# service
# ['appointment', 'customeroriente', 'be']
# service
# ['staff', 'to', 'go', 'soon', 'be', 'lady', 'be']
# service
# ['employee', 'reach', 'chance', 'have', 'tell']
# service
# ['assistant', 'tell']
# service
# ['of', 'experience', 'everything', 'play']
# service
# ['consultant', 'reischl', 'center', 'in', 'experience', 'everything', 'play']
# service
# ['advisor', 'reischl', 'take', 'recommend']
# service
# ['class', 'thank', 'as', 'clean', 'vacuum', 'be', 'rip']
# service
# ['consultant', 'car', 'need', 'know']
# service
# ['advisor', 'be', 'bring']
# service
# ['by', 'consultation', 'add', 'have', 'enter', 'appointment', 'despite', 'take', 'be', 'have']
# service
# ['advisor', 'be', 'give', 'have']
# service
# ['for', 'audi', 'with', 'be', 'have', 'have']
# service
# ['to', 'come', 'report', 'be', 'have', 'have']
# service
# ['be', 'help', 'book']
# service
# ['advice', 'for', 'thank', 'like', 'want']
# service
# ['imagine', 'thank', 'like', 'want']
# service
# ['etcmany', 'for', 'visit', 'want']
# service
# ['advisor', 'take', 'be', 'have', 'do']
# service
# ['answer', 'look', 'time', 'take', 'be', 'have', 'do']
# service
# ['use', 'have', 'do']
# service
# ['wait', 'tell']
# service
# ['advisor', 'squeeze', 'be', 'be']
# service
# ['thumb', 'for', 'approach', 'leave']
# service
# ['in', 'put', 'start', 'ask']
# service
# ['repair', 'be', 'start', 'ask']
# service
# ['go', 'start', 'ask']
# service
# ['include', 'go', 'allow']
# service
# ['with', 'unwashed', 'get', 'allow']
# service
# ['in', 'use', 'ask', 'drive', 'let', 'be']
# service
# ['be', 'go', 'have']
# service
# ['in', 'car', 'have']
# service
# ['get', 'thank']
# service
# ['call', 'cancellation', 'agree']
# service
# ['appointment', 'have', 'message', 'get', 'agree']
# service
# ['in', 'do', 'touch', 'assure']
# service
# ['enjoy', 'redeem', 'bring', 'able', 'be']
# service
# ['suckedtiptop', 'wash', 'finish', 'be', 'thank']
# service
# ['desert', 'arrogance', 'of', 'respect', 'be', 'make', 'understand']
# service
# ['assistant', 'thank', 'like', 'give']
# service
# ['get', 'figure', 'staff', 'collect', 'transfer', 'promise', 'time', 'go', 'be']
# service
# ['appointment', 'make', 'able', 'be', 'staff', 'in', 'treat', 'be', 'be', 'be', 'understand']
# service
# ['man', 'be', 'serve', 'treat', 'be', 'be', 'be', 'understand']
# service
# ['get', 'appointment', 'make', 'give', 'able', 'be', 'rate', 'understand']
# service
# ['about', 'opinion', 'be']
# service
# ['opinion', 'be']
# service
# ['advisor', 'weimann', 'be', 'wish', 'be', 'be']
# service
# ['describe']
# service
# ['be']
# service
# ['do', 'have', 'be']
# service
# ['car', 'pick', 'at', 'request', 'm', 'say', 'purchase', 'be']
# service
# ['terminal', 'at', 'pick', 'at', 'request', 'm', 'say', 'purchase', 'be']
# service
# ['go']
# service
# ['be', 'reverse', 'regard', 'go']
# service
# ['employee', 'shine', 'tell']
# service
# ['staff', 'be', 'shortcoming', 'enclose', 'shine', 'tell']
# service
# ['afford', 'tell']
# service
# ['ma', 'be', 'ask', 'be']
# service
# ['be', 'want', 'go', 'drive', 'sound']
# service
# ['staff', 'by', 'pick', 'sound']
# service
# ['dream', 'in', 'take', 'pick', 'sound']
# service
# ['area', 'in', 'need', 'have']
# service
# ['center', 'to', 'go', 'have']
# service
# ['mahag', 'contact', 'try', 'meantime', 'be', 'promise', 'headquarters', 'from', 'unsuccessful', 'be', 'have', 'have']
# service
# ['staff', 'call', 'at', 'be', 'albrechtstrasse', 'make', 'be']
# service
# ['through', 'start', 'be', 'receive', 'discuss', 'make', 'be']
# service
# ['be']
# service
# ['desert', 'pure', 'come', 'give']
# service
# ['consultant', 'top', 'be']
# service
# ['advisor', 'strike', 'be']
# service
# ['consultant', 'call', 'be', 'be', 'be', 'tell', 'be', 'tell']
# service
# ['manager', 'ring', 'call', 'receive', 'tell']
# service
# ['ma', 'inform', 'wait', 'exchange', 'be', 'pass', 'explain', 'tell']
# service
# ['with', 'in', 'interested', 'be', 'feel']
# service
# ['in', 'people', 'train', 'be', 'tell']
# service
# ['employee', 'replace']
# service
# ['for', 'present', 'have', 'be']
# service
# ['take']
# service
# ['employee', 'get', 'etcif', 'receive', 'receive']
# service
# ['consultant', 'to', 'promise', 'be', 'receive']
# service
# ['consultant', 'call', 'try', 'be']
# service
# ['turn', 'read', 'weaken']
# service
# ['dealership', 'be']
# service
# ['about', 'complain', 'turn', 'be']
# service
# ['employee', 'of', 'motivation', 'due', 'be', 'be', 'make']
# service
# ['whether', 'have', 'keep', 'have']
# service
# ['guarantee', 'km', 'about', 'have', 'style', 'be', 'make', 'be', 'come']
# service
# ['to', 'come', 'happy', 'be', 'advice', 'be', 'have']
# service
# ['for', 'help', 'have', 'be']
# service
# ['for', 'pay', 'like', 'present']
# service
# ['acceptance', 'regard', 'be']
# service
# ['employee', 'as', 'emphasize']
# service
# ['to', 'appointment', 'for', 'request', 'pass', 'say', 'go', 'have']
# service
# ['be']
# service
# ['to', 'thank', 'help', 'be']
# service
# ['do']
# service
# ['repair', 'have', 'time', 'be', 'send', 'card', 'have', 'be', 'be', 'service', 'do']
# service
# ['consultant', 'gebert', 'pick']
# service
# ['bring', 'pick']
# service
# ['receipt', 'of', 'head', 'by', 'greet', 'be', 'appointment', 'without', 'sign', 'come', 'be', 'admit']
# service
# ['desert', 'germany', 'use', 'admit']
# service
# ['for', 'model', 'as', 'serve', 'say', 'admit']
# service
# ['audi', 'car', 'of', 'purchase', 'with', 'satisfied', 'be', 'be', 'turn', 'provide']
# service
# ['for', 'compliment', 'pick', 'able', 'be', 'provide']
# service
# ['advisordespite', 'avoid']
# service
# ['wean']
# service
# ['employee', 'get', 'of', 'chance', 'wean']
# service
# ['competent', 'staff', 'know', 'dealership']
# service
# ['error', 'experience', 'day', 'get', 'be']
# service
# ['because', 'drive', 'decide', 'be']
# service
# ['center', 'service', 'because', 'drive', 'decide', 'be']
# service
# ['at', 'be']
# service
# ['plantin', 'to', 'forward', 'be', 'be']
# service
# ['consultant', 'as', 'helpful', 'be', 'service', 'plantin', 'to', 'forward', 'be', 'be']
# service
# ['for', 'come', 'be', 'service', 'plantin', 'to', 'forward', 'be', 'be']
# service
# ['managerhere', 'by', 'greet', 'be']
# service
# ['lekie', 'from', 'advice', 'relate']
# service
# ['after', 'appear', 'drive', 'have']
# service
# ['for', 'properlythank', 'be']
# service
# ['with', 'experience', 'have', 'think']
# service
# ['colleague', 'come', 'sit', 'think']
# service
# ['adviser', 'be', 'wait', 'have', 'dealership', 'learn']
# service
# ['have']
# service
# ['be']
# service
# ['be']
# service
# ['be', 'be']
# service
# ['consultant', 'for', 'be']
# service
# ['employee', 'thank']
# service
# ['staff', 'thank']
# service
# ['to', 'turn', 's', 'think', 'have']
# service
# ['appointment', 'make', 'want']
# service
# ['do', 'ready', 'be', 'call', 'get']
# service
# ['be', 'fact', 'to', 'use', 'be', 'work', 'want']
# service
# ['employee', 'fix', 'ask']
# service
# ['case', 'in', 'with', 'treat', 'manage']
# service
# ['employee', 'pretend', 'be']
# service
# ['with', 'happy', 'be']
# service
# ['desert', 'to', 'welcome', 'be']
# service
# ['mean', 'be', 'know', 'be']
# service
# ['imagine', 's']
# service
# ['premium', 's']
# service
# ['advisor', 'reischl', 'martens', 'in', 'helpful', 'appointment', 'without', 'be']
# service
# []
# service
# ['appointment', 'to', 'appointment', 'be']
# service
# ['team', 'find', 'go', 'be']
# service
# ['for', 'be']
# service
# ['stand']
# service
# []
# service
# ['eg', 'fast', 'help']
# service
# ['appointment', 'experience', 'understand']
# service
# ['with', 'satisfied', 'be']
# service
# ['tüv', 'naviupdate']
# service
# ['consultant', 'of', 'help', 'team', 'naviupdate']
# service
# ['with', 'satisfied', 'be']
# service
# ['with', 'dealership', 'be']
# service
# ['eater', 'service', 'with', 'dealership', 'be']
# service
# ['experience', 'thank']
# service
# ['be']
# service
# ['by', 'serve', 'be']
# service
# ['with', 'dealership']
# service
# ['consultant', 'to', 'friendly', 'assistant', 'forward', 'zink', 'lady', 'by', 'greet']
# service
# ['assistant', 'forward', 'zink', 'lady', 'by', 'greet']
# service
# ['advice', 'for', 'thank']
# service
# ['despite', 'carry']
# service
# ['be']
# service
# ['be']
# service
# ['sale', 'to', 'look', 'be']
# service
# ['be']
# service
# ['for', 'thank', 'be']
# service
# []
# service
# ['advice', 'offer', 'know']
# service
# ['with', 'satisfied', 'be']
# service
# ['be']
# service
# ['mentality', 'mechanic', 'be']
# service
# ['with', 'satisfied', 'be']
# service
# ['explain']
# service
# []
# service
# ['assistant', 'keep']
# service
# ['team', 'buy']
# service
# ['thank']
# service
# ['keep']
# service
# ['be']
# service
# ['workshop']
# service
# ['service', 'workshop']
# service
# ['workshop']
# service
# ['service', 'workshop']
# service
# ['of', 'support', 'for', 'thank']
# service
# ['communication', 'thank', 'like']
# service
# ['finish']
# service
# ['keep']
# service
# ['be']
# service
# ['thank']
# service
# ['car', 'perfect']
# service
# ['be']
# service
# ['desert', 'germany', 'in', 'gem', 'give']
# service
# []
# service
# []
# service
# []
# service
# ['thank']
# service
# ['of', 'trace', 'overbooke']
# service
# ['for', 'wait', 'have']
# service
# ['thank']
# service
# ['staff']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['call', 'for', 'charge', 'ignore', 'treat']
# service
# []
# service
# ['advisor', 'be', 'look', 'like']
# service
# ['of', 'sale', 'advisor', 'be', 'look', 'like']
# service
# ['effort', 'to', 'thank', 'make', 'be', 'accompany']
# service
# ['be', 'do']
# service
# ['for', 'discuss', 'find', 'colanero', 'do']
# service
# ['with', 'dissatisfied', 'be']
# service
# ['appointment', 'have']
# service
# ['employee', 'handling', 'thank']
# service
# ['sale', 'in', 'handling', 'thank']
# service
# ['cost', 'of', 'pricing', 'with', 'with', 'satisfied', 'be', 'be', 'look', 'be']
# service
# ['impeccable', 'staff']
# service
# ['process', 'experience']
# service
# ['advisor', 'colaneroi', 'experience']
# service
# ['event', 'experience']
# service
# ['stay', 'recommend', 'have', 'experience']
# service
# ['advisor', 'colanero', 'with', 'trudere', 'recommend', 'have', 'experience']
# service
# ['advisor', 'be']
# service
# ['get', 'belief', 'in', 'go']
# service
# ['offer', 'have', 'go']
# service
# ['purchase', 'have', 'hope']
# service
# ['advisor', 'colanero', 'by', 'acceptance', 'to', 'experience', 'be']
# service
# ['be', 'be', '🤣', 'be', 'like']
# service
# ['contact', 'with', 'make', 'write']
# service
# ['at', 'drive', 'be', 'thank']
# service
# ['be', 'committed', 'be', 'change']
# service
# ['herethank', 'recommend']
# service
# ['schmidt', 'do', 'be']
# service
# ['issue', 'for', 'be', 'colanero', 'to', 'go', 'get', 'feel']
# service
# ['car', 'take']
# service
# ['experience', 'be', 'recommend']
# service
# ['experiencedhe', 'skill', 'of', 'lot', 'with', 'play', 'be']
# service
# ['above', 'about', 'enthusiastic', 'be', 'buy']
# service
# ['be', 'ask', 'necessary', 'think', 'lay']
# service
# ['orientation', 'advice', 'thank']
# service
# ['advisor', 'thank', 'to', 'acceptance', 'from', 'appearance', 'love']
# service
# ['top', 'dealership', 'like']
# service
# ['to', 'purchase', 'due', 'buyer', 'after', 'be', 'have']
# service
# ['tire', 'be', 'have']
# service
# ['commit']
# service
# ['parking', 'dealership', 'be']
# service
# ['advice', 'for', 'thank']
# service
# ['team', 'colanero', 'thank', 'like']
# service
# ['to', 'from', 'wow', 'wow', 'see']
# service
# ['from', 'kümmel', 'take']
# service
# ['alessandro', 'colanero', 'service', 'friendly', 'building']
# service
# ['friendly', 'building']
# service
# []
# service
# ['get', 'be', 'say', 'have', 'plan']
# service
# ['expire', 'recommend']
# service
# ['team', 'tiptop', 'expire', 'recommend']
# service
# ['with', 'enthusiastic', 'satisfied', 'be']
# service
# ['audi', 'with', 'happy', 'be']
# service
# ['experience']
# service
# ['patience', 'with', 'provide', 'experience']
# service
# ['for', 'recommend', 'experience']
# service
# ['friendliness', 'in', 'happen']
# service
# ['employee', 'get', 'try', 'happen']
# service
# ['appointment', 'get', 'like', 'write', 'apart', 'answer', 'happen']
# service
# ['acceptance', 'carry']
# service
# ['of', 'scope', 'beyond', 'repair', 'acceptance', 'carry']
# service
# ['status', 'visit', 'on', 'date', 'to', 'keep', 'carry']
# service
# ['acceptance', 'be']
# service
# ['with', 'satisfied', 'be', 'point']
# service
# ['be', 'point']
# service
# ['repair', 'work', 'be', 'plan', 'be', 'check', 'recommend', 'point']
# service
# ['guide', 'be', 'talk', 'fun', 'be']
# service
# ['be']
# service
# ['friendliness', 'value', 'behavior', 'with', 'disappointed', 'be', 'ask', 'notice', 'finance']
# service
# ['charge', 'be', 'be']
# service
# ['be', 'be']
# service
# ['cost', 'bring', 'be']
# service
# ['point', 'from', 'get']
# service
# ['change', 'for', 'happy', 'm']
# service
# ['from', 'schmidt', 'be', 'be', 'm']
# service
# ['industry', 'in', 'selfemploye', 'be']
# service
# ['be', 'know', 'selfemploye', 'be']
# service
# ['die', 'be', 'know', 'selfemploye', 'be']
# service
# ['department', 'in', 'haßelbeck', 'by', 'look', 'honor', 'have']
# service
# ['experience', 'be', 'guy', 'have']
# service
# ['about', 'enthusiastic', 'be']
# service
# ['watch', 'notice']
# service
# ['with', 'satisfied', 'be', 'have', 'be', 'say', 'take', 'smell']
# service
# ['of', 'level', 'by', 'surprise']
# service
# ['for', 'responsible', 'those', 'to', 'compliment', 'surprise']
# service
# ['with', 'satisfied', 'be', 'know', 'surprise']
# service
# ['for', 'appointment', 'make', 'attempt', 'in', 'follow', 'know', 'surprise']
# service
# ['be', 'know', 'reproach', 'let', 'abwatschen', 'have', 'know', 'surprise']
# service
# ['do', 'let', 'abwatschen', 'have', 'know', 'surprise']
# service
# ['advisor', 'be']
# service
# ['have']
# service
# ['with', 'satisfied', 'be', 'have']
# service
# ['adviser', 'of', 'friendliness', 'acceptance', 'be', 'have']
# service
# ['for', 'serve', 'advise']
# service
# ['about', 'question', 'have', 'call']
# service
# ['sale', 'between', 'difference', 'with', 'positive', 'be']
# service
# ['workshop', 'difference', 'with', 'positive', 'be']
# service
# ['to', 'loyal', 'be', 'customer', 'for', 'match', 'be', 'extent', 'to', 'be', 'be', 'be']
# service
# ['sale', 'be', 'look', 'be']
# service
# ['appointment', 'to', 'customer', 'as', 'care', 'impress']
# service
# ['on', 'problem', 'explain', 'manner', 'impress']
# service
# ['deliver', 'be', 'bite']
# service
# ['staff', 'be']
# service
# ['tüv', 'go']
# service
# ['staff', 'for', 'wait', 'point']
# service
# ['employee', 'indication', 'wait', 'point']
# service
# ['advisorservice']
# service
# ['appointment', 'with', 'call', 'find', 'find']
# service
# ['agent', 'tell', 'condescend', 'discussion', 'after', 'thank', 'stop', 'be']
# service
# ['advice', 'recommend', 'convince', 'look']
# service
# ['representative', 'be']
# service
# ['be', 'be', 'forgive', 'm']
# service
# ['seem', 'give']
# service
# ['partner', 'for', 'look', 'have', 'give']
# service
# ['experience', 'with', 'thrill', 'be', 'ready', 'be']
# service
# ['appointment', 'to', 'be', 'find']
# service
# ['be', 'be', 'find']
# service
# ['support', 'communication']
# service
# ['carry', 'have']
# service
# ['mahag', 'trudering', 'of', 'beware', 'want']
# service
# ['be', 'want']
# service
# ['administration', 'acceptance', 'in', 'brain', 'due', 'expect']
# service
# ['point', 'want', 'decide', 'happen', 'show']
# service
# ['interval', 'due', 'mahag', 'frequent']
# service
# ['with', 'satisfied', 'be', 'buy']
# service
# ['to', 'berlin', 'telephone', 'contact', 'with', 'start', 'buy']
# service
# ['seem', 'apology', 'be', 'delay', 'make', 'answer', 'be', 'know', 'be', 'point']
# service
# ['advice', 'give', 'be']
# service
# ['deadline', 'be']
# service
# ['use', 'happy', 'be', 'carry', 'be']
# service
# ['employee', 'tell', 'go']
# service
# ['employee', 'for', 'star', 'be', 'wait', 'please']
# service
# ['recommend']
# service
# ['for', 'sm', 'be']
# service
# ['employee', 'be', 'offer']
# service
# ['handling', 'in', 'be', 'everything', 'setting', 'factory', 'memory', 'go', 'know']
# service
# ['employee', 'treat', 'be']
# service
# ['team', 'quake', 'have', 'time', 'write']
# service
# ['master', 'team', 'quake', 'have', 'time', 'write']
# service
# ['to', 'be', 'write']
# service
# ['with', 'service', 'to', 'be', 'write']
# service
# ['provider', 'by', 'have', 'need', 'be', 'write']
# service
# ['advisor', 'be', 'go']
# service
# ['employee', 'by', 'confirm', 'want']
# service
# ['repair', 'see', 'make']
# service
# ['advice', 'moisture', 'build']
# service
# ['team', 'do']
# service
# ['be']
# service
# ['operator', 'hang']
# service
# ['teach', 'recommendable', 'hang']
# service
# ['sale', 'give']
# service
# ['with', 'satisfied', 'be']
# service
# ['advisor', 'haßelbeck', 'with', 'satisfied', 'be']
# service
# ['recommend', 'be']
# service
# ['appointment', 'be']
# service
# ['improve', 'for', 'lot', 'be']
# service
# ['have']
# service
# ['in', 'appointment', 'have', 'have']
# service
# ['do', 'have', 'buy', 'have']
# service
# ['for', 'be']
# service
# ['building', 'recommend']
# service
# ['processing']
# service
# ['annoy']
# service
# ['appointment', 'after', 'call', 'annoy']
# service
# ['recommendthank']
# service
# ['employee']
# service
# ['thank']
# service
# []
# service
# ['advisor', 'rauch', 'know']
# service
# ['good', 'invoice', 'turn']
# service
# ['thank']
# service
# []
# service
# ['employee']
# service
# ['around', 'reliable', 'thank']
# service
# []
# service
# ['disrespectful', 'staff']
# service
# []
# service
# ['elsethank', 'expect']
# service
# ['thank']
# service
# []
# service
# ['thankskind', 'regardserwin', 'as']
# service
# ['have']
# service
# []
# service
# ['for', 'thank']
# service
# ['trust', 'dealer']
# service
# ['callback', 'get']
# service
# []
# service
# ['friendly', 'team', 'recommend']
# service
# ['etc', 'run']
# service
# ['smooth', 'handling', 'impeccable']
# service
# ['as']
# service
# []
# service
# []
# service
# ['employee', 'take', 'have']
# service
# []
# service
# []
# service
# ['be']
# service
# ['employee', 'send']
# service
# []
# service
# []
# service
# ['offer']
# service
# []
# service
# ['surprise']
# service
# ['lose', 'come']
# service
# ['be', 'order']
# service
# ['meet']
# service
# ['charge', 'meet']
# service
# ['communication', 'ingolstadtthank']
# service
# ['in', 'rent']
# service
# ['staff']
# service
# []
# service
# []
# service
# ['as']
# service
# []
# service
# ['car']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['bring']
# service
# ['be', 'bring']
# service
# ['illuminate', 'having', 'despite', 'be', 'appointment', 'get']
# service
# ['be', 'get']
# service
# ['consultation', 'pickup', 'acceptance', 'service', 'be', 'get']
# service
# ['ratio', 'with', 'concern', 'be', 'anything', 'say', 'friendly', 'be']
# service
# ['experience', 'continue']
# service
# ['herefor', 'buy', 'experience', 'continue']
# service
# ['employee', 'inform', 'ask', 'slip', 'find', 'want', 'feeling', 'have', 'seem', 'respond']
# service
# ['staff', 'selection', 'educate', 'car', 'be', 'sell']
# service
# ['do', 'ask', 'get', 'call']
# service
# ['for', 'appointment', 'make', 'put', 'call']
# service
# ['manager', 'from', 'answer', 'be', 'think', 'call', 'nothing', 'for', 'account', 'be', 'say', 'say', 'call']
# service
# ['contract', 'have', 'say']
# service
# ['at', 'as', 'be', 'feel', 'buy']
# service
# ['advice', 'with', 'satisfied', 'be']
# service
# ['partner', 'be']
# service
# ['carry', 'be', 'be']
# service
# ['for', 'charge', 'be']
# service
# ['advisor', 'to', 'message', 'be', 'want', 'strengthen', 'be', 'be']
# service
# ['at', 'have']
# service
# ['be', 'house', 'be']
# service
# ['car', 'for', 'advice', 'top', 'be', 'house', 'be']
# service
# ['be', 'feel']
# service
# ['fit', 'be', 'be']
# service
# ['pickup', 'for', 'thank']
# service
# ['work', 'pickup', 'for', 'thank']
# service
# ['with', 'dealership']
# service
# ['dealer', 'partner', 'offer', 'time', 'for', 'get']
# service
# ['have']
# service
# ['feel']
# service
# ['in', 'people', 'of', 'rest', 'be']
# service
# []
# service
# ['quality', 'for', 'serve']
# service
# ['be']
# service
# ['make']
# service
# ['change']
# service
# ['be']
# service
# ['staff']
# service
# ['experience']
# service
# ['thank']
# service
# ['staff']
# service
# ['be']
# service
# ['by', 'service', 'be']
# service
# ['for', 'thank']
# service
# ['to', 'go']
# service
# ['from', 'man', 'phone', 'meantime', 'turn', 'be', 'go']
# service
# ['mean', 'show', 'go']
# service
# ['of', 'matter', 'be', 'be']
# service
# ['competentvery', 'be', 'be', 'be']
# service
# ['staff']
# service
# ['be']
# service
# ['process', 'run', 'be', 'have']
# service
# ['advice']
# service
# ['for', 'be']
# service
# ['industry', 'in', 'bit', 'for', 'hope', 'be']
# service
# ['be', 'offer', 'be']
# service
# ['staff', 'offer', 's']
# service
# ['programming', 'have']
# service
# ['after', 'washing']
# service
# ['be']
# service
# ['behavior', 'describe', 'occur', 'have']
# service
# ['be', 'be']
# service
# ['be']
# service
# ['vw']
# service
# ['use', 'vw']
# service
# ['appointment', 'receive']
# service
# ['vehicle']
# service
# ['get']
# service
# ['be']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['be']
# service
# []
# service
# ['level', 'fast']
# service
# ['for', 'time', 'next', 'buy', 'be']
# service
# ['people']
# service
# ['thank']
# service
# ['employee', 'photograph', 'be', 'carry']
# service
# ['be', 'carry', 'carry']
# service
# ['work', 'carry', 'have', 'recommend', 'carry']
# service
# ['manager', 'apologize', 'convince']
# service
# ['be']
# service
# ['on', 'come', 'make', 'try', 'be']
# service
# ['thank']
# service
# ['appointment', 'have']
# service
# ['advisor', 'riedmeir', 'by', 'greet', 'be', 'have']
# service
# ['advisor', 'get', 'explain', 'pick', 'explain', 'have']
# service
# ['consultant', 'include', 'get', 'explain', 'pick', 'explain', 'have']
# service
# ['thank']
# service
# ['answer', 'ready', 'be', 'thank']
# service
# ['be', 'be', 'serve', 'be', 'be']
# service
# ['of', 'knowledge', 'of', 'level', 'car', 'with', 'satisfied', 'be', 'fact', 'be', 'convince', 'be', 'be', 'avoid', 'order', 'in', 'change', 'lease']
# service
# ['zitzelsberger', 'be']
# service
# ['have', 'buy', 'know']
# service
# ['be']
# service
# ['to', 'take']
# service
# ['employee', 'for', 'wait', 'have', 'be', 'be']
# service
# ['about', 'excited', 'be', 'be']
# service
# ['staff', 'be', 'stress', 'riedl', 'have']
# service
# ['be']
# service
# ['drive', 'be']
# service
# ['change', 'do', 'thank', 'have', 'continue']
# service
# ['advisor', 'from', 'advice', 'readyagain', 'information', 'call', 'be', 'receive', 'be', 'have']
# service
# ['be', 'be', 'receive', 'be', 'have']
# service
# ['after', 'satisfied', 'be']
# service
# ['manager', 'with', 'contact', 'be', 'get', 'be']
# service
# ['offer', 'have']
# service
# ['do', 'have', 'buy', 'have']
# service
# ['employee', 'from', 'problem', 'drop', 'pay', 'find', 'have']
# service
# ['sale', 'give']
# service
# ['work', 'be']
# service
# ['have', 'm']
# service
# ['thank']
# service
# ['for', 'leave']
# service
# ['adviser', 'step', 'by', 'explain', 'leave']
# service
# ['with', 'problem', 'since', 'identify', 'buy', 'be', 'say', 'have', 'do']
# service
# ['employee', 'help', 'shoulda', 'answer', 'find']
# service
# ['be', 'help', 'shoulda', 'answer', 'find']
# service
# []
# service
# []
# service
# ['case', 'for', 'be', 'be', 'expect']
# service
# ['experience', 'be', 'be', 'expect']
# service
# ['be', 'end', 'hear', 'be', 'say', 'inform', 'know', 'expect']
# service
# ['get', 'want']
# service
# ['work', 'call', 'be', 'have', 'know', 'make', 'promise', 'be']
# service
# ['drive', 'want', 'be']
# service
# ['go', 'postpone']
# service
# ['of', 'form', 'in', 'offer', 'accept', 'offer', 'follow', 'ask']
# service
# ['give', 'answer', 'receive', 'accept', 'offer', 'follow', 'ask']
# service
# ['I', 'for', 'comply', 'want', 'about', 'thinking', 'without', 'make', 'annoy', 'pass', 'like', 'assume', 'arise']
# service
# ['be', 'workshop', 'with', 'satisfied', 'be', 'buy', 'get']
# service
# ['manager', 'ventilation', 'to', 'due', 'go', 'replace']
# service
# ['staff', 'impeccable', 'communication', 'be']
# service
# ['use', 'recommend']
# service
# ['firstclass', 'advice', 'by', 'give', 'get']
# service
# ['employee', 'be', 'go']
# service
# ['for', 'get', 'wonder', 'have', 'exchange', 'have', 'have']
# service
# ['recommend']
# service
# ['advice', 'be', 'find']
# service
# ['thank']
# service
# ['work']
# service
# ['for', 'thank', 'be', 'thank']
# service
# ['change']
# service
# ['be', 'buy']
# service
# ['after', 'be', 'be']
# service
# ['with', 'satisfied', 'be', 'buy']
# service
# ['provide', 'be']
# service
# ['with', 'fzg', 'have']
# service
# ['for', 'be']
# service
# ['at', 'be']
# service
# ['advisormr', 'popali', 'to', 'advice', 'be']
# service
# []
# service
# ['friendly', 'staff', 'be']
# service
# ['have']
# service
# ['include']
# service
# ['be', 'feel']
# service
# []
# service
# ['do', 'be']
# service
# ['be']
# service
# ['repair', 'helpedfor', 'be']
# service
# ['for', 'appointment', 'get']
# service
# ['in', 'work', 'get']
# service
# ['with', 'dealership']
# service
# ['include']
# service
# ['from', 'car', 'have']
# service
# ['advice', '🏻']
# service
# []
# service
# ['be']
# service
# ['for', 'value']
# service
# ['processing']
# service
# ['staff']
# service
# ['pick', 'staff']
# service
# []
# service
# []
# service
# []
# service
# ['staff']
# service
# ['thank']
# service
# ['advice']
# service
# []
# service
# ['space', 'find', 'hard']
# service
# ['workshop']
# service
# []
# service
# ['person']
# service
# ['advice']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['help']
# service
# ['performance', 'for', 'price', 'be']
# service
# []
# service
# ['atmosphere']
# service
# []
# service
# []
# service
# ['staff', 'advice']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['get']
# service
# ['with', 'reliable', 'get']
# service
# ['communication', 'of', 'amount', 'be', 'be']
# service
# ['advisor', 'from', 'letter', 'to', 'response', 'of', 'most', 'for', 'fault', 'admit', 'behave', 'talk']
# service
# ['management', 'from', 'from', 'letter', 'to', 'response', 'of', 'most', 'for', 'fault', 'admit', 'behave', 'talk']
# service
# ['for', 'ask']
# service
# ['request', 'in', 'warranty', 'in', 'buy', 'ask']
# service
# ['exclude', 'determine', 'have', 'ask']
# service
# ['car', 'with', 'contact', 'have', 'something', 'be', 'go', 'disappointed', 'm', 'pick']
# service
# ['be']
# service
# ['from', 'print', 'after', 'be']
# service
# ['😆', 'bring']
# service
# ['beat', 'buy']
# service
# ['appointment', 'have', 'answer', 'be']
# service
# ['with', 'dealership', 'be']
# service
# ['be']
# service
# ['vw', 'at', 'customeroriente', 'be']
# service
# ['partner', 'be', 'be']
# service
# ['advice']
# service
# ['to', 'drive', 'be', 'be']
# service
# ['make']
# service
# ['in', 'blow', 'be']
# service
# ['of', 'one', 'be', 'buy', 'be']
# service
# ['manager', 'by', 'call', 'relate']
# service
# ['dealership', 'bring', 'time', 'be', 'deliver', 'be', 'see']
# service
# ['to', 'go', 'wait', 'mention', 'notice', 'give', 'have']
# service
# ['try']
# service
# ['for', 'charge', 'try', 'be', 'show']
# service
# ['be', 'recommend', 'recognize', 'far', 'go', 'proceed', 'prevent', 'pull', 'show']
# service
# ['employee', 'on', 'depend', 'have', 'fear']
# service
# ['employee', 'with', 'experience', 'have', 'fear']
# service
# ['repair', 'be', 'find', 'call', 'be', 'find', 'be', 'have', 'fear']
# service
# ['know', 'dealership', 'for', 'look', 'allow']
# service
# ['expect', '€', 'for', 'buy', 'be', 'be', 'find', 'buy']
# service
# ['in', 'be', 'recommend']
# service
# ['advisor', 'forget', 'status', 'about', 'worry', 'have', 'have']
# service
# ['sale', 'be']
# service
# ['say']
# service
# ['with', 'satisfied', 'be']
# service
# ['thank']
# service
# ['to', 'satisfied', 'be', 'buy']
# service
# ['advice', 'buy']
# service
# []
# service
# ['be']
# service
# ['be']
# service
# ['price']
# service
# ['employee', 'service']
# service
# []
# service
# ['advice']
# service
# []
# service
# []
# service
# ['thank']
# service
# ['allround', 'service', 'thank']
# service
# ['value', 'be']
# service
# ['with', 'dealership', 'thank']
# service
# ['reliable']
# service
# ['be']
# service
# []
# service
# []
# service
# ['provide', 'be', 'buy']
# service
# ['for', 'thank', 'ensure', 'be', 'buy']
# service
# ['be', 'document', 'answer', 'waa', 'ask']
# service
# ['for', 'mrschmid']
# service
# ['recommend']
# service
# ['to', 'recommend']
# service
# []
# service
# ['about', 'anything', 'say', 'conclude', 'want']
# service
# ['get']
# service
# ['be', 'car', 'get', 'get']
# service
# ['be', 'recommend']
# service
# ['buy']
# service
# ['quality', 'receive', 'buy']
# service
# ['be']
# service
# ['forget']
# service
# ['lease', 'decide', 'dealership']
# service
# ['be']
# service
# ['staffyou', 'enter']
# service
# ['audizentrum', 'from', 'feedback', 'get', 'tell']
# service
# ['wait', 'inform', 'be', 'recommend']
# service
# ['with', 'problem', 'have', 'understand']
# service
# ['for', 'buy', 'competent', 'see']
# service
# ['request', 'due', 'receive']
# service
# ['desk', 'at', 'treat', 'drive']
# service
# ['dedicated', 'employee', 'accept']
# service
# ['for', 'thank']
# service
# []
# service
# ['miserablethe', 'seller', 'carspurchase', 'reach']
# service
# ['with', 'inconsistency', 'be', 'reach']
# service
# ['employee', 'find', 'solution', 'in', 'interested', 'objective', 'find', 'make', 'reject']
# service
# ['staff', 'with', 'discuss', 'journey', 'take', 'refuel', 'have', 'call', 'come']
# service
# ['be', 'order', 'say']
# service
# ['center', 'with', 'order', 'with', 'experience', 'do']
# service
# ['purchase', 'handover', 'be', 'be', 'be']
# service
# ['give', 'be', 'be', 'be']
# service
# ['remain', 'advertise']
# service
# ['for', 'thank', 'positive', 'greeting', 'be', 'want']
# service
# ['look', 'want']
# service
# ['for', 'register', 'want']
# service
# ['in', 'have', 'most', 'drive', 'be', 'want']
# service
# ['for', 'car', 'register', 'want', 'drive', 'be', 'want']
# service
# ['look']
# service
# []
# service
# ['staff', 'be']
# service
# ['acceptance', 'satisfied']
# service
# ['be', 'satisfied']
# service
# ['be', 'deal', 'buy']
# service
# ['advice', 'offer', 'with', 'satisfied', 'be', 'buy']
# service
# ['be']
# service
# ['for', 'service', 'be']
# service
# ['courteous', 'staff', 'include']
# service
# ['from', 'buy', 'recommend']
# service
# ['be']
# service
# ['advice']
# service
# ['help']
# service
# ['buy']
# service
# ['with', 'satisfied', 'mileage', 'with', 'buy']
# service
# ['be']
# service
# []
# service
# ['leave']
# service
# ['advice', 'keep']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['location', 'price']
# service
# []
# service
# ['sale']
# service
# ['thank']
# service
# []
# service
# []
# service
# []
# service
# ['on', 'be', 'have', 'support', 'concern']
# service
# ['sort', 'say', 'pick', 'be', 'ensure', 'try', 'be', 'concern']
# service
# []
# service
# ['from', 'advice', 'thank']
# service
# ['be', 'be', 'think']
# service
# ['for', 'express', 'like']
# service
# ['make', 'need', 'show', 'fetch', 'see', 'want']
# service
# ['describe', 'like']
# service
# ['advice', 'with', 'satisfied', 'be', 'buy', 'like']
# service
# ['provide', 'hermann', 'salesperson', 'highlight', 'want', 'be', 'go', 'be', 'be', 'like']
# service
# ['stop', 'like']
# service
# ['in', 'pick', 'manage', 'take', 'work', 'say', 'have', 'buy']
# service
# ['buy', 'buy']
# service
# ['of', 'term', 'in', 'treat', 'be', 'buy', 'receive']
# service
# ['department', 'have', 'store', 'be', 'expect', 'have', 'receive']
# service
# ['concept', 'come', 'receive']
# service
# ['be', 'go', 'have', 'have']
# service
# ['friendliness', 'disappoint', 'buy', 'receive']
# service
# ['buy']
# service
# ['advice', 'with', 'satisfied', 'be', 'be']
# service
# ['vehicle', 'make', 'say', 'have', 'buy']
# service
# ['problem', 'have', 'help', 'be']
# service
# ['under', 'wash', 'pay']
# service
# ['advice', 'be', 'buy']
# service
# ['be', 'say', 'compare', 'competition', 'from', 'drive', 'advise', 'find', 'advice', 'for', 'thank', 'have', 'come']
# service
# ['look', 'be']
# service
# ['vehicle', 'for', 'thank', 'handle', 'look', 'write']
# service
# ['serve', 'emphasize', 'like', 'time', 'at', 'buy', 'write']
# service
# ['by', 'center', 'buy']
# service
# ['office', 'from', 'callback', 'assure']
# service
# ['be', 'assure']
# service
# ['be', 'expect', 'be']
# service
# ['be', 'say', 'have', 'process', 'of', 'take', 'sell', 'pick']
# service
# ['with', 'satisfied', 'be']
# service
# ['buy']
# service
# ['with', 'dealership', 'go']
# service
# ['to', 'come', 'customer', 'be']
# service
# ['about', 'enthusiastic', 'be', 'be']
# ...
# service
# ['seem', 'make']
# service
# ['look', 'about', 'clueless', 'be', 'want']
# service
# ['seller', 'recommend', 'be']
# service
# ['change', 'for', 'estimate', 'offer', 'have']
# service
# ['change', 'for', 'price', 'make', 'bring', 'have']
# service
# ['change', 'to', 'go']
# service
# ['be']
# service
# ['price', 'meet']
# service
# ['be', 'be']
# service
# ['be', 'convince']
# service
# ['with', 'perfect', 'be']
# service
# ['sale', 'be', 'feel']
# service
# []
# service
# ['staff', 'service']
# service
# ['think']
# service
# ['staff', 'seller', 'be']
# service
# []
# service
# ['friendly', 'force']
# service
# ['force']
# service
# ['value']
# service
# ['happy']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['manager', 'marcel', 'from', 'support', 'receive', 'be']
# service
# ['be']
# service
# ['cost', 'staff', 'part', 'service', 'be']
# service
# ['anything', 'for', 'responsible', 'be', 'be']
# service
# ['for', 'againgreat', 'do', 'love', 'thank']
# service
# ['of', 'term', 'in', 'train', 'think', 'workshop', 'at', 'experience']
# service
# ['with', 'happy']
# service
# ['be']
# service
# ['despite', 'lack', 'be', 'carry']
# service
# ['in', 'include', 'car', 'service', 'despite', 'lack', 'be', 'carry']
# service
# ['contact', 'provide', 'be', 'carry']
# service
# ['from', 'advice', 'be']
# service
# ['take', 'be']
# service
# ['thank', 'wish', 'like']
# service
# ['be', 'be']
# service
# ['with', 'happy', 'be', 'buy']
# service
# ['be', 'workshop', 'find']
# service
# ['for', 'greatthank', 'receive']
# service
# ['be', 'implement', 'be', 'buy']
# service
# ['team', 'be', 'have']
# service
# ['acceptance', 'be', 'be', 'have']
# service
# ['as', 'know', 'have']
# service
# ['for', 'look', 'be', 'seem', 'callback', 'ask', 'date', 'about', 'email', 'be', 'try', 'assure', 'think']
# service
# ['be']
# service
# ['happenedvery']
# service
# ['top', 'car', 'thank']
# service
# []
# service
# ['advisor', 'appointment', 'with', 'start', 'be', 'be']
# service
# ['matter', 'schmeling', 'by', 'advise', 'use', 'buy']
# service
# ['provide', 'with', 'satisfied', 'be']
# service
# ['be', 'make', 'be']
# service
# ['be']
# service
# ['find', 'respond']
# service
# ['leave', 'buy', 'help']
# service
# ['car', 'be', 'work']
# service
# ['processing']
# service
# ['answer', 'be', 'answer', 'write']
# service
# ['okay']
# service
# ['loyalty', 'about', 'get', 'be', 'be', 'receive', 'be']
# service
# ['on', 'place', 'be', 'give']
# service
# ['be', 'buy']
# service
# ['sale', 'staff', 'ambience', 'by', 'maintain']
# service
# ['car']
# service
# ['by', 'give', 'buy']
# service
# ['deficiency', 'forget', 'be', 'recommend', 'realize']
# service
# ['advice', 'thank']
# service
# ['advisor', 'over', 'seller', 'from', 'accommodate', 'repair', 'bring', 'buy']
# service
# ['with', 'dealership', 'be']
# service
# ['have']
# service
# ['after', 'run', 'try']
# service
# ['with', 'dealership', 'see', 'find', 'feel']
# service
# ['for', 'appointment', 'get', 'enough', 'be', 'be', 'show']
# service
# ['thank', 'be', 'show']
# service
# ['be']
# service
# ['purchase', 'of', 'term', 'in', 'number', 'be', 'be']
# service
# ['accident', 'damage', 'purchase', 'skoda', 'customer', 'go']
# service
# ['employee', 'be', 'allow']
# service
# ['be', 'find', 'pay', 'allow']
# service
# ['provide', 'with', 'dissatisfied', 'be', 'performance', 'have', 'inform', 'investigation', 'during', 'be', 'find', 'pay', 'allow']
# service
# ['problemconclusion', 'be', 'ask', 'have']
# service
# ['advisor', 'tekin', 'with', 'satisfied', 'be', 'be']
# service
# ['for', 'time', 'be', 'be', 'want']
# service
# ['be', 'write', 'be', 'see']
# service
# ['for', 'thank', 'do']
# service
# ['staff', 'buy', 'come']
# service
# ['sale', 'employee', 'be', 'judge', 'possible', 'be', 'share']
# service
# ['receive', 'own']
# service
# ['be']
# service
# ['team', 'with', 'continue', 'hope', 'come']
# service
# ['at', 'odyssey', 'after', 'learn']
# service
# ['top', 'be']
# service
# ['from', 'advice', 'with', 'satisfied', 'be']
# service
# ['worker', 'thank']
# service
# ['for', 'hamza', 'thank']
# service
# []
# service
# ['salesman', 'be']
# service
# ['good', 'staff', 'be']
# service
# ['get', 'justify']
# service
# ['from', 'positive', 'report', 'be']
# service
# ['make']
# service
# ['after', 'be']
# service
# ['support', 'advice', 'with', 'start']
# service
# ['in', 'dealership']
# service
# ['ignore']
# service
# []
# service
# ['accommodate']
# service
# ['staff', 'buy']
# service
# []
# service
# ['about', 'trust', 'of', 'dealer']
# service
# ['advice']
# service
# ['be']
# service
# ['advice', 'for', 'rauch', 'thank']
# service
# []
# service
# ['get', 'buy', 'dealership']
# service
# ['be']
# service
# ['be']
# service
# ['be']
# service
# ['above', 'difference', 'make', 'm', 'service', 'be']
# service
# ['intoxicate']
# service
# ['like', 'super', 'everything', 'make', 'have']
# service
# ['for', 'spell', 'hope', 'thank']
# service
# ['consultant', 'autohaus', 'recommend']
# service
# ['have']
# service
# ['thank']
# service
# ['in', 'use', 'thank']
# service
# ['thank']
# service
# ['gag', 'carry']
# service
# ['be']
# service
# []
# service
# ['thank']
# service
# ['thank']
# service
# ['service', 'atmosphere', 'be']
# service
# ['atmosphere', 'be']
# service
# ['see']
# service
# ['workshop', 'be']
# service
# ['nice', 'contact']
# service
# ['thank']
# service
# []
# service
# ['thank']
# service
# []
# service
# ['be']
# service
# []
# service
# []
# service
# ['thank']
# service
# ['be', 'be', 'wish']
# service
# []
# service
# ['do']
# service
# ['service', 'do']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['staff']
# service
# ['be']
# service
# ['seem']
# service
# ['be']
# service
# []
# service
# ['get']
# service
# ['take']
# service
# ['offer']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['people']
# service
# []
# service
# []
# service
# []
# service
# ['workshop', 'uncomplicated', 'competent', 'everything', 'give']
# service
# []
# service
# ['top', 'say']
# service
# ['advisor', 'talk', 'be', 'say']
# service
# ['contract', 'despite', 'inspect', 'after', 'talk', 'be', 'say']
# service
# ['partner', 'with', 'decide', 'change', 'bring', 'be', 'get', 'agree']
# service
# ['advice', 'impress', 'be']
# service
# []
# service
# ['for', 'express', 'like', 'coffee', 'with', 'unbureaucratic', 'prepared', 'be', 'confirm']
# service
# ['with', 'be']
# service
# ['be', 'be']
# service
# []
# service
# ['quality', 'deteriorate', 'come']
# service
# ['with', 'wait', 'forgive', 'be']
# service
# ['appointment', 'be', 'have', 'have', 'stand']
# service
# ['be', 'nothing', 'leave']
# service
# ['with', 'happy', 'be', 'be']
# service
# ['processing', 'be', 'answer', 'be', 'buy']
# service
# ['recommendtop', 'search']
# service
# ['do', 'let', 'be', 'hear']
# service
# ['advice', 'take']
# service
# ['agree', 'call']
# service
# ['salesperson', 'customer', 'while', 'for', 'stand', 'point', 'get']
# service
# ['offer', 'be', 'look', 'workshop', 'different', 'know', '€', 'for', 'vacuum', 'footwell', 'get']
# service
# ['perform', 'have', 'recommend']
# service
# ['be', 'recommend']
# service
# ['about', 'complain']
# service
# ['carry', 'have', 'impression', 'buy', 'have']
# service
# ['for', 'pay', 'willing', 'be']
# service
# ['receive']
# service
# ['work', 'after', 'look', 'be', 'be']
# service
# ['consultant', 'by', 'call']
# service
# ['consultanti', 'with', 'interview', 'for', 'take', 'disappointed', 'be', 'say', 'matter', 'call']
# service
# ['staff', 'do', 'have']
# service
# ['buy']
# service
# ['manager', 'with', 'conversation', 'for', 'retrospect', 'in', 'thank', 'like', 'plug', 'find', 'advise']
# service
# ['to', 'leave', 'handover', 'until', 'advise']
# service
# ['be', 'be']
# service
# ['sale', 'without', 'request', 'refuse', 'have']
# service
# ['nothing', 'word', 'know', 'let', 'guess']
# service
# ['on', 'rely', 'buy', 'say']
# service
# ['be']
# service
# ['wait']
# service
# ['thereabsolute', 'people', 'dealership', 'recommend', 'be']
# service
# ['appointment', 'key', 'for', 'reachable', 'make']
# service
# ['for', 'call', 'have', 'be', 'realize', 'be', 'realize']
# service
# ['with', 'before', 'be', 'treat', 'car', 'buy']
# service
# ['do', 'vehicle', 'be', 'mention', 'explain', 'carry', 'be', 'announce', 'have', 'notice']
# service
# ['be', 'be']
# service
# ['for', 'misinformation', 'be']
# service
# ['with', 'satisfied', 'be', 'feel', 'welcome', 'for', 'thank']
# service
# ['desert', 'in', 'hope', 'be']
# service
# ['thank', 'germanywa', 'hope', 'be']
# service
# ['be']
# service
# ['be']
# service
# ['staff', 'be']
# service
# ['to', 'perfectstarte', 'be']
# service
# ['staff']
# service
# []
# service
# ['staff', 'like']
# service
# ['seller']
# service
# []
# service
# ['contact']
# service
# ['type', 'about', 'enthusiastic', 'be', 'be']
# service
# ['experience']
# service
# []
# service
# ['advice']
# service
# []
# service
# []
# service
# ['thank', 'go']
# service
# ['schwalbe', 'to', 'go']
# service
# ['be', 'receive']
# service
# ['in', 'experience']
# service
# ['to', 'clarify', 'handle', 'be', 'experience']
# service
# ['in', 'center', 'from', 'audi', 'lease', 'receive']
# service
# ['with', 'satisfied', 'be']
# service
# ['be', 'have', 'be', 'be']
# service
# ['staff', 'of', 'effort', 'for', 'thank', 'thank']
# service
# ['call', 's', 'audi', 'take', 'able', 'be', 'ask']
# service
# ['be', 'drive']
# service
# ['staff', 'to', 'thank', 'resolve', 'drive']
# service
# ['to', 'purchase', 'from', 'be']
# service
# ['department', 'in', 'do', 'be']
# service
# ['of', 'field', 'in', 'expert', 'be', 'be']
# service
# ['from', 'usual', 'as']
# service
# ['be']
# service
# ['for', 'procure', 'be', 'be']
# service
# ['expertise', 'seller', 'use']
# service
# ['care', 'be']
# service
# ['provide', 'for', 'care', 'be']
# service
# ['sale', 'in', 'cut', 'be', 'be']
# service
# ['service', 'recommend']
# service
# ['recommend']
# service
# ['in', 'time', 'on', 'by', 'by', 'care', 'feel']
# service
# ['service', 'thank']
# service
# ['thank']
# service
# ['advice', 'with', 'satisfied', 'employee', 'advice', 'be']
# service
# ['advisor', 'with', 'end', 'start', 'say']
# service
# ['thank']
# service
# ['sale', 'in', 'experience', 'have', 'customer', 'be']
# service
# ['guarantee', 'include', 'buy', 'recommend']
# service
# ['be', 'show', 'be', 'be', 'want']
# service
# ['advice', 'from', 'team', 'to', 'thank', 'be']
# service
# ['by', 'surprise', 'buy', 'be']
# service
# ['by', 'surprised', 'be', 'be']
# service
# ['staff']
# service
# ['friendliness']
# service
# ['manager', 'employee', 'for', 'be']
# service
# []
# service
# ['be']
# service
# ['person', 'cofinance']
# service
# ['be', 'satisfied', 'be']
# service
# ['of', 'top', 'be', 'satisfied', 'be']
# service
# ['advice', 'be']
# service
# ['center', 'be', 'be', 'wolleswinkel']
# service
# ['of', 'explanation', 'manager', 'to', 'talk', 'time', 'be', 'give', 'want']
# service
# ['car', 'keep']
# service
# ['advisor', 'be']
# service
# ['offer', 'help', 'keep']
# service
# ['recommend']
# service
# ['friendly', 'staff', 'be']
# service
# ['provider', 'look', 'be']
# service
# ['advicekeep']
# service
# ['with', 'dealership']
# service
# ['staff']
# service
# ['friendly', 'staff', 'selection']
# service
# ['team', 'professional']
# service
# ['fit', 'as', 'staff']
# service
# ['get']
# service
# []
# service
# ['recommend']
# service
# ['help', 'be']
# service
# ['help', 'be']
# service
# ['staff']
# service
# []
# service
# ['thank', 'purchase']
# service
# ['in', 'operation', 'thank']
# service
# []
# service
# []
# service
# ['thank']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['😍']
# service
# ['👌']
# service
# []
# service
# []
# service
# ['cost', 'company', 'through', 'resell', 'be']
# service
# ['answer', 'go']
# service
# ['advisor', 'for', 'wait', 'have', 'be']
# service
# ['advisor', 'for', 'wait', 'have']
# service
# ['for', 'thank', 'like', 'place', 'be', 'enter', 'receive']
# service
# ['for', 'go', 's', 'offer']
# service
# ['advisor', 'with', 'be', 'offer']
# service
# ['advisor', 'to', 'back', 'get', 'be', 'say', 'offer']
# service
# ['advisor', 'annoy', 'expectation', 'to', 'contrary', 'get', 'be', 'say', 'offer']
# service
# ['maintenance', 'for', 'be']
# service
# ['car', 'get']
# service
# ['be']
# service
# ['about', 'enthusiastic', 'be', 'refer']
# service
# ['sale', 'of', 'combination', 'opportunity', 'get', 'make', 'get', 'ask', 'be']
# service
# ['advice', 'for', 'thank', 'have', 'buy']
# service
# ['reliable']
# service
# ['of', 'field', 'in', 'say', 'of', 'regardless', 'reliable']
# service
# ['with', 'experience', 'have', 'need']
# service
# ['sale', 'be']
# service
# ['manfre', 'lämmermann', 'in', 'sale', 'be']
# service
# ['to', 'go']
# service
# ['be', 'flawless', 'be', 'cause', 'happen']
# service
# ['industry', 'in', 'everywhere', 'buy', 'think', 'be']
# service
# ['with', 'cooperation', 'to', 'emotiondue', 'without', 'change', 'be', 'be', 'compare', 'think', 'be']
# service
# ['advisor', 'be', 'be', 'compare', 'think', 'be']
# service
# ['with', 'experience', 'have', 'have']
# service
# ['by', 'pick', 'have']
# service
# ['advisor', 'go', 'lease', 'by', 'cover', 'be', 'check']
# service
# ['with', 'satisfied', 'be', 'help', 'pass', 'fact', 'be', 'be', 'memory', 'have', 'check']
# service
# ['with', 'continue']
# service
# ['conclusion', 'imagine', 's', 'dealership', 'change', 'reason', 'give', 'do', 'take', 'question', 'continue']
# service
# ['car', 'inspection', 'be']
# service
# ['purchase', 'to', 'lead', 'franz', 'from', 'advice', 'be']
# service
# ['to', 'accord', 'be', 'be']
# service
# ['visit', 'car', 'buy', 'come', 'team', 'take']
# service
# ['team', 'thank']
# service
# ['cut']
# service
# ['be']
# service
# ['teamsuch', 'thank']
# service
# ['desert', 'in', 'find', 'service', 'teamsuch', 'thank']
# service
# ['advice', 'be', 'problem', 'be']
# service
# ['like']
# service
# ['audi', 'recommend']
# service
# ['advisor', 'have', 'espresso', 'take', 'find']
# service
# ['carry', 'have', 'be', 'defect', 'have']
# service
# ['do', 'allow', 'workshop', 'by', 'carry', 'have', 'be', 'defect', 'have']
# service
# ['advisor', 'be', 'have', 'be', 'defect', 'have']
# service
# ['germany', 'of', 'topic', 'fit', 'have']
# service
# ['department', 'of', 'head', 'to', 'thank', 'give', 'have']
# service
# ['satisfaction', 'advice', 'be']
# service
# ['advisor', 'everything', 'do']
# service
# ['be', 'commit']
# service
# ['in', 'have', 'king', 'be', 'be', 'commit']
# service
# ['about', 'anything', 'say', 'nice']
# service
# ['for', 'thank', 'like']
# service
# ['advisor', 'pötzsch', 'günes', 'salesman', 'to', 'give', 'like', 'do', 'like']
# service
# ['break']
# service
# ['advisor', 'to', 'keep']
# service
# ['get', 'have', 'dealership', 'like', 'be', 'feel']
# service
# ['dealership', 'be']
# service
# ['staff', 'sven']
# service
# ['staff', 'car']
# service
# ['force', 'be', 'everything', 'with', 'satisfied', 'be']
# service
# ['price', 'receive', 'buy']
# service
# ['consultant', 'with', 'deal', 'have']
# service
# []
# service
# ['thank']
# service
# ['sell']
# service
# ['staff', 'worth']
# service
# ['staff', 'be']
# service
# ['selection', 'top']
# service
# ['thank']
# service
# ['with', 'satisfied']
# service
# []
# service
# []
# service
# ['do']
# service
# ['märz', 'with', 'meet', 'do']
# service
# []
# service
# ['salesperson', 'reception', 'of', 'regardless', 'be', 'offer']
# service
# ['offer']
# service
# ['car', 'be']
# service
# ['with', 'satisfied', 'be']
# service
# ['from', 'order', 'vehicle', 'be', 'be']
# service
# ['be', 'have']
# service
# ['handling', 'advice', 'photo', 'see', 'have']
# service
# ['care', 'care']
# service
# ['from', 'expect', 'everything']
# service
# ['of', 'handling', 'of', 'description', 'to', 'correspond', 'blind', 'buy']
# service
# ['pickup', 'be']
# service
# ['be']
# service
# ['employee', 'quality']
# service
# ['be', 'call', 'note']
# service
# ['be', 'answer', 'be', 'drive']
# service
# ['with', 'satisfied', 'be', 'recommend']
# service
# ['carsfor', 'use', 'meet', 'time', 'take', 'be', 'know', 'surprise']
# service
# ['accommodating']
# service
# ['provide', 'by', 'surprise', 'include']
# service
# ['appointment', 'request', 'of', 'processing', 'take', 'be', 'surprise', 'include']
# service
# ['cost', 'include']
# service
# ['price', 'in', 'include']
# service
# ['look', 'be', 'think']
# service
# ['from', 'tire', 'order', 'recommend']
# service
# ['complaint', 'experience']
# service
# ['provide', 'able', 'employee', 'make', 'experience']
# service
# ['than', 'more', 'be', 'be', 'note']
# service
# ['staff', 'be', 'be', 'note']
# service
# ['history', 'from', 'apparent', 'recognizable', 'be', 'turn', 'require']
# service
# ['advisor', 'thank']
# service
# ['solutionoriente', 'consultant', 'be']
# service
# ['mechanic', 'consultant', 'be']
# service
# ['for', 'thank']
# service
# ['business', 'ie', 'car', 'as', 'audi']
# service
# ['play']
# service
# ['be']
# service
# ['happy']
# service
# ['contact', 'access']
# service
# []
# service
# ['choice']
# service
# []
# service
# ['advice']
# service
# ['advise']
# service
# []
# service
# []
# service
# ['crowd']
# service
# []
# service
# []
# service
# ['thank']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 6514    None
# 6515    None
# 6516    None
# 6517    None
# 6518    None
# Name: lemma_eng_review, Length: 6519, dtype: object

# %%
# the tokens which depens on "service"
def dependency_on(text):
    doc=nlp_eng(text)
    for token in doc:
        if token.text == "service":
            print(token.text)
            children = [t.text for t in token.children]
            print(children)

# %%
english["lemma_eng_review"].apply(lambda x: dependency_on(x))
# Out:
# service
# ['excellent', 'and', 'experience']
# service
# []
# service
# ['orient']
# service
# ['good']
# service
# ['amazing', 'kind', 'but', 'expensive']
# service
# []
# service
# ['good', 'people']
# service
# ['good']
# service
# ['good']
# service
# ['great']
# service
# ['the', 'and', 'quality']
# service
# ['good']
# service
# []
# service
# []
# service
# ['transparency', 'customer']
# service
# ['my', 'customer']
# service
# []
# service
# ['the', 'at', 'in']
# service
# ['the']
# service
# []
# service
# ['audi']
# service
# ['excellent', 'by']
# service
# ['good', 'from', 'break', 'and', 'be', 'pick']
# service
# []
# service
# ['competent']
# service
# ['the', 'competent', 'courteous', 'at']
# service
# ['great', 'be']
# service
# []
# service
# []
# service
# []
# service
# ['delivery', 'and']
# service
# ['friendly', 'from', 'after', 'buy', '😀']
# service
# []
# service
# ['this', 'good']
# service
# ['and', 'customer']
# service
# ['the']
# service
# []
# service
# ['and', 'oil']
# service
# []
# service
# ['reliable', 'friendly', 'good', 'and', 'service']
# service
# []
# service
# ['great', 'and', 'staff']
# service
# ['top', 'friendly']
# service
# ['team', 'enthusiastic', 'run']
# service
# ['the', 'top']
# service
# ['a', 'vw', 'audi']
# service
# []
# service
# []
# service
# []
# service
# ['ready', 'top', 'competent']
# service
# []
# service
# ['good']
# service
# ['good', 'in']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['this', 'one', 'or']
# service
# ['a', 'damage', 'customer']
# service
# ['great']
# service
# []
# service
# ['part']
# service
# ['the', 'friendly', 'like']
# service
# ['the', 'perfect']
# service
# ['top']
# service
# ['the', 'competent']
# service
# ['super', 'run']
# service
# []
# service
# ['great', 'nice', 'and', 'friendlythank']
# service
# []
# service
# []
# service
# ['customer']
# service
# ['the', 'great', 'by']
# service
# ['possibletop']
# service
# []
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# ['great', 'dealing']
# service
# ['great']
# service
# []
# service
# ['quicklythe', 'customer', 'from']
# service
# ['the', 'basic']
# service
# ['the', 'great', 'in']
# service
# []
# service
# ['another', 'hourgood']
# service
# ['great']
# service
# []
# service
# ['quick', 'customer']
# service
# []
# service
# ['super']
# service
# ['the', 'part']
# service
# ['the', 'part', 'without']
# service
# []
# service
# ['the', 'first', 'and', 'washing']
# service
# ['customer']
# service
# ['the', 'and', 'performance']
# service
# []
# service
# []
# service
# ['this', 'customer']
# service
# ['customer']
# service
# []
# service
# ['perfect']
# service
# ['the']
# service
# []
# service
# []
# service
# ['a', 'great', 'customer']
# service
# []
# service
# []
# service
# ['pleasantthe']
# service
# []
# service
# ['the', 'and', 'incident']
# service
# ['emergency']
# service
# ['a', 'solution', 'customer', 'and', 'satisfaction']
# service
# []
# service
# ['top']
# service
# []
# service
# []
# service
# ['the']
# service
# ['a', 'to']
# service
# ['professional']
# service
# ['and', 'wheel']
# service
# ['top', 'and', 'minkus']
# service
# ['exceptional', 'customer']
# service
# ['a', 'simple', 'of']
# service
# ['the', 'customer']
# service
# []
# service
# []
# service
# []
# service
# ['poor', 'customer']
# service
# []
# service
# ['fast']
# service
# ['good']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'at']
# service
# []
# service
# ['excellent']
# service
# ['top']
# service
# []
# service
# ['a', 'great']
# service
# ['good']
# service
# ['a', 'pick', 'hand', 'be']
# service
# []
# service
# ['delivery']
# service
# ['advice', 'great', 'and', 'friendly']
# service
# []
# service
# ['the']
# service
# ['friendly', 'and', 'competence']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['the', 'poor']
# service
# []
# service
# []
# service
# []
# service
# ['great', 'and', 'staff']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'change']
# service
# ['otherwise']
# service
# ['the', 'in']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'to']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'eveningthe', 'in', 'recommend']
# service
# ['and', 'repair']
# service
# []
# service
# []
# service
# ['the']
# service
# ['deficient']
# service
# ['an', 'appointment', 'great']
# service
# ['audi']
# service
# ['commission']
# service
# ['great']
# service
# []
# service
# []
# service
# ['friendly', 'and', 'processingcompetence']
# service
# ['good']
# service
# []
# service
# ['a', 'with']
# service
# []
# service
# []
# service
# []
# service
# ['nice', 'customer']
# service
# ['great']
# service
# ['excellent', 'after']
# service
# []
# service
# ['reliable', 'thorough', 'satisfied']
# service
# ['great', 'courteous', 'as', 'staff']
# service
# ['finally', 'a', 'good', 'have', 'be']
# service
# []
# service
# ['and', 'sale']
# service
# ['will', 'the', 'and', 'above']
# service
# []
# service
# ['super']
# service
# ['wait', 'customersallround']
# service
# ['great']
# service
# []
# service
# ['bad']
# service
# ['the', 'aftersale']
# service
# ['the', 'excellent', 'customer', 'of', 'and']
# service
# ['good']
# service
# ['the', 'friendly', 'on']
# service
# ['workshop']
# service
# []
# service
# ['friendly']
# service
# ['I']
# service
# ['fast', 'unproblematic', 'solutionoriented']
# service
# []
# service
# ['great']
# service
# []
# service
# ['excellent']
# service
# ['pickup']
# service
# ['professional', 'and', 'advice']
# service
# ['email']
# service
# ['a', 'simple']
# service
# ['great']
# service
# ['reliable']
# service
# ['the', 'zmuda']
# service
# ['good']
# service
# ['super']
# service
# []
# service
# ['fast', 'with']
# service
# ['top']
# service
# []
# service
# ['great', 'and', 'helpful']
# service
# []
# service
# []
# service
# ['good', 'in', 'employee']
# service
# ['perfect']
# service
# ['friendly', 'as', 'processing']
# service
# []
# service
# ['the']
# service
# ['team', 'friendly', 'as', 'from']
# service
# ['great']
# service
# ['super', 'person']
# service
# ['good', 'and', 'service']
# service
# ['customer']
# service
# ['good']
# service
# ['the', 'online']
# service
# ['good']
# service
# ['great']
# service
# []
# service
# []
# service
# ['perfect', 'from']
# service
# ['super', 'from']
# service
# []
# service
# ['great', 'and', 'team']
# service
# ['good']
# service
# ['top', 'staff', 'again']
# service
# ['pellet', 'super']
# service
# ['the', 'great']
# service
# ['pleasant']
# service
# ['good', 'friendly']
# service
# ['top', 'and', 'support']
# service
# ['top', 'from']
# service
# ['good']
# service
# ['fast']
# service
# ['the', 'good']
# service
# ['top', 'for']
# service
# ['top']
# service
# ['good', 'as']
# service
# ['good', 'always']
# service
# ['good']
# service
# ['great']
# service
# ['audi', 'here', 'since', 'thank']
# service
# []
# service
# []
# service
# ['the', 'poor', 'customer']
# service
# []
# service
# ['client']
# service
# ['bad']
# service
# ['the']
# service
# ['a', 'good']
# service
# ['the', 'road', 'excellent']
# service
# ['a']
# service
# []
# service
# []
# service
# ['their']
# service
# []
# service
# []
# service
# ['other', 'audivw']
# service
# ['a', 'routine']
# service
# ['the', 'do']
# service
# []
# service
# []
# service
# ['moneyvery', 'poor']
# service
# ['the', 'receive']
# service
# ['customer']
# service
# []
# service
# []
# service
# ['the', 'in']
# service
# ['the']
# service
# ['good', 'hospitalitygood']
# service
# ['the']
# service
# ['top']
# service
# ['all', 'a', 'great']
# service
# []
# service
# []
# service
# ['the', 'by']
# service
# []
# service
# []
# service
# []
# service
# ['bad', 'audi']
# service
# ['reliable', 'customer', 'by', 'with', 'and', 'deal']
# service
# ['audi']
# service
# ['mega']
# service
# ['customer']
# service
# []
# service
# ['all']
# service
# ['nice', 'that']
# service
# []
# service
# ['my', 'audi']
# service
# ['an', 'repair', 'top', 'competent']
# service
# ['the', 'date', 'customer']
# service
# ['audi']
# service
# ['the', 'customer', 'at']
# service
# []
# service
# []
# service
# ['good']
# service
# []
# service
# ['month']
# service
# ['bad', 'tel']
# service
# []
# service
# []
# service
# []
# service
# ['customer']
# service
# []
# service
# ['customer']
# service
# []
# service
# []
# service
# ['appointment']
# service
# ['the', 'outstanding', 'customer', 'by', 'and', 'advice']
# service
# ['the', 'from']
# service
# ['customer']
# service
# ['good', 'audi', 'from', 'carry', 'top']
# service
# ['customer']
# service
# ['great', 'from']
# service
# ['advice', 'great', 'and', 'handling']
# service
# ['customer']
# service
# ['every', 'regular', 'customer']
# service
# ['great']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['the', 'oil']
# service
# []
# service
# []
# service
# ['the', 'good']
# service
# []
# service
# ['eg', 'auto']
# service
# ['audi']
# service
# []
# service
# ['the', 'upcoming']
# service
# ['the', 'quick']
# service
# ['audi']
# service
# []
# service
# ['and']
# service
# ['the']
# service
# []
# service
# []
# service
# ['the']
# service
# []
# service
# ['the']
# service
# []
# service
# ['the', 'good', 'and', 'approach']
# service
# ['my', 'last']
# service
# ['water']
# service
# ['team']
# service
# ['the', 'great']
# service
# []
# service
# ['a', 'unique', 'feel']
# service
# ['the', 'frisch']
# service
# []
# service
# ['the']
# service
# []
# service
# ['nice', 'customer', 'with']
# service
# []
# service
# ['the', 'usual']
# service
# []
# service
# ['the']
# service
# ['tüv']
# service
# []
# service
# []
# service
# ['a', 'perfect']
# service
# ['good', 'customer', 'and', 'advice', 'from', 'and', 'processing']
# service
# []
# service
# ['the', 'of']
# service
# []
# service
# ['the', 'normal', 'have']
# service
# ['the']
# service
# []
# service
# ['customer']
# service
# []
# service
# ['audi', 'super']
# service
# []
# service
# ['the', 'good']
# service
# ['excellent']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'associated', 'understand']
# service
# ['perfect', 'acceptance']
# service
# ['perfect']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['execution']
# service
# []
# service
# []
# service
# []
# service
# ['and', 'support']
# service
# []
# service
# ['dealershipour']
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# []
# service
# ['and', 'repair']
# service
# []
# service
# ['the']
# service
# ['this', 'firsttime', 'in']
# service
# ['premium', 'and', 'tariff']
# service
# []
# service
# []
# service
# ['the', 'at']
# service
# ['the']
# service
# ['poor', 'of', 'spend']
# service
# []
# service
# ['good']
# service
# ['this', 'workshopregarde', 'customer']
# service
# []
# service
# ['the', 'first']
# service
# ['the']
# service
# ['incomplete']
# service
# ['the', 'last']
# service
# ['such', 'a', 'premium']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['seat', 'audi']
# service
# ['courteous', 'be']
# service
# []
# service
# []
# service
# []
# service
# ['this']
# service
# []
# service
# []
# service
# ['more', 'customer']
# service
# ['the', 'at', 'in']
# service
# ['sensationalthe']
# service
# []
# service
# ['the']
# service
# ['hello', 'everybodythe', 'knowhow', 'staff']
# service
# ['the']
# service
# []
# service
# []
# service
# ['excellent', 'customer']
# service
# ['the', 'here']
# service
# []
# service
# ['record']
# service
# ['such', 'a', 'lousy', 'customer']
# service
# ['the']
# service
# ['the']
# service
# []
# service
# ['real']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['the', 'and', 'advice']
# service
# []
# service
# ['audi', 'sport']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['this']
# service
# ['customer']
# service
# ['great', 'in']
# service
# []
# service
# ['good']
# service
# []
# service
# []
# service
# []
# service
# ['his', 'customer']
# service
# ['the']
# service
# ['various', 'thing', 'sincesuper']
# service
# []
# service
# ['tire', 'change', 'or', 'repair']
# service
# ['bad', 'customer']
# service
# ['the', 'next']
# service
# ['the', 'great']
# service
# ['good']
# service
# ['audi']
# service
# []
# service
# ['the']
# service
# ['top', 'servicesuper', 'great']
# service
# ['the', 'part', 'martens']
# service
# ['bad', 'and', 'focus', 'be']
# service
# []
# service
# []
# service
# ['great']
# service
# []
# service
# []
# service
# ['aspire']
# service
# ['the', 'in']
# service
# ['this', 'premium', 'customer']
# service
# ['unfriendly', 'staff']
# service
# ['no']
# service
# []
# service
# ['great']
# service
# []
# service
# ['this', 'annoying', 'non', 'center']
# service
# []
# service
# ['the', 'in']
# service
# ['the', 'be']
# service
# []
# service
# ['the']
# service
# ['the']
# service
# ['personal']
# service
# []
# service
# ['the', 'top']
# service
# ['the', 'audi', 'of']
# service
# ['promise']
# service
# []
# service
# ['the', 'experience', 'super', 'work', 'care', 'from']
# service
# ['no', 'customer']
# service
# ['fast', 'great', 'compliment', 'to']
# service
# ['quick', 'top']
# service
# ['mr', 'michael', 'mordstein']
# service
# []
# service
# []
# service
# ['audi', 'customer']
# service
# []
# service
# ['the']
# service
# ['a', 'free']
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# []
# service
# []
# service
# ['good', 'staff']
# service
# []
# service
# []
# service
# ['great', 'from']
# service
# []
# service
# []
# service
# ['the', 'same']
# service
# ['bad']
# service
# ['great', 'and', 'repair']
# service
# []
# service
# []
# service
# ['the', 'be']
# service
# []
# service
# []
# service
# ['the', 'customer', 'and', 'support']
# service
# ['excellent', 'eater']
# service
# []
# service
# []
# service
# ['the', 'of']
# service
# ['mr', 'reischl', 'top']
# service
# ['great']
# service
# []
# service
# ['part', 'salessuper']
# service
# ['the', 'good', 'to']
# service
# ['hail', 'top']
# service
# ['fast']
# service
# ['the', 'tire', 'with']
# service
# []
# service
# ['great', 'reischel']
# service
# ['the', 'and', 'car']
# service
# ['a', 'great', 'customer', 'recommend']
# service
# []
# service
# ['the', 'customer', 'and', 'support']
# service
# []
# service
# ['customer']
# service
# ['the', 'receive']
# service
# ['top', 'friendly', 'time']
# service
# ['good']
# service
# []
# service
# ['perfect']
# service
# ['good']
# service
# ['friendly', 'reception', 'fast']
# service
# ['great', 'from']
# service
# ['great', 'and', 'service']
# service
# ['courteous']
# service
# ['great', 'and', 'service']
# service
# ['courteous']
# service
# ['the', 'on']
# service
# ['consulting']
# service
# ['fast']
# service
# ['super']
# service
# ['the']
# service
# ['super', 'and', 'repair']
# service
# []
# service
# ['good', 'and', 'care', 'by']
# service
# []
# service
# ['super', 'and', 'advice', 'from']
# service
# ['good', 'and', 'staff']
# service
# ['good', 'and', 'deal']
# service
# ['great', 'with']
# service
# ['express']
# service
# ['from']
# service
# ['super', 'fast']
# service
# ['courteous']
# service
# ['great', 'from']
# service
# ['good', 'and', 'deal']
# service
# ['great', 'always']
# service
# ['good', 'in']
# service
# ['nice']
# service
# ['top', 'and', 'help']
# service
# ['great']
# service
# ['bad']
# service
# ['good']
# service
# ['perfect']
# service
# ['top']
# service
# []
# service
# ['friendly', 'staff', 'good']
# service
# []
# service
# ['a', 'be']
# service
# ['registration']
# service
# ['the', 'first', 'on', 'and']
# service
# ['this', 'great']
# service
# ['the']
# service
# []
# service
# ['great']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['professional', 'here']
# service
# ['premium']
# service
# ['the', 'plan']
# service
# []
# service
# ['customer', 'of']
# service
# []
# service
# ['the', 'last']
# service
# ['the', 'car']
# service
# []
# service
# ['the', 'customer']
# service
# []
# service
# ['top']
# service
# []
# service
# ['super']
# service
# ['all', 'the', 'customer']
# service
# ['else']
# service
# []
# service
# []
# service
# []
# service
# ['to']
# service
# ['change', 'advice', 'and', 'education']
# service
# ['great']
# service
# ['friendly']
# service
# ['great']
# service
# []
# service
# ['z', 'perfect']
# service
# []
# service
# []
# service
# ['colanero', 'perfect']
# service
# ['fast', 'remove']
# service
# ['the', 'perfect', 'allround', 'from']
# service
# ['every']
# service
# ['and', 'staff']
# service
# ['the', 'from']
# service
# ['the']
# service
# ['satisfaction', 'top', 'and', 'advice']
# service
# ['outstanding', 'customer']
# service
# ['your', 'top', 'and', 'feeling']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# ['and', 'repair']
# service
# []
# service
# ['the', 'with']
# service
# ['advisor', 'upon']
# service
# []
# service
# ['great']
# service
# ['the', 'seller']
# service
# []
# service
# []
# service
# ['and', 'replacement', 'of']
# service
# ['the', 'alone']
# service
# ['audi']
# service
# ['the', 'here']
# service
# ['the']
# service
# []
# service
# ['such', 'an', 'exceptional']
# service
# ['cruise', 'todaytop']
# service
# []
# service
# []
# service
# ['the', 'workshop', 'coordination']
# service
# ['outthe', 'bad', 'have']
# service
# ['the', 'of']
# service
# []
# service
# ['the']
# service
# ['the']
# service
# ['the', 'leasing']
# service
# ['the']
# service
# ['the']
# service
# []
# service
# ['the', 'first', 'inspection']
# service
# ['all', 'v']
# service
# []
# service
# ['the', 'regular', 'and', 'tüv']
# service
# ['the', 'do']
# service
# []
# service
# ['the']
# service
# ['the', 'for']
# service
# ['recognizable', 'conclusion']
# service
# []
# service
# ['the', 'vehicle']
# service
# ['perfect']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['customer']
# service
# ['good']
# service
# ['customer']
# service
# ['the']
# service
# ['this']
# service
# ['audi']
# service
# ['the', 'perfect']
# service
# []
# service
# ['the']
# service
# []
# service
# ['my', 'audis', 'first', 'major']
# service
# []
# service
# ['the']
# service
# []
# service
# ['good']
# service
# []
# service
# ['the', 'like']
# service
# ['the', 'personal']
# service
# ['this', 'customer']
# service
# ['support']
# service
# []
# service
# ['this']
# service
# []
# service
# []
# service
# ['top']
# service
# ['a', 'make', 'confirm']
# service
# []
# service
# []
# service
# ['top']
# service
# []
# service
# []
# service
# ['warranty', 'with', 'as']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# ['such', 'a', 'bad']
# service
# ['appointment', 'great']
# service
# ['audi', 'trudering']
# service
# ['top']
# service
# []
# service
# ['that', 'customer']
# service
# []
# service
# ['the', 'of']
# service
# []
# service
# ['this', 'good']
# service
# []
# service
# []
# service
# ['good']
# service
# ['the']
# service
# ['the']
# service
# ['with']
# service
# ['competent', 'and', 'nice', 'be']
# service
# ['great']
# service
# ['good', 'customer']
# service
# []
# service
# ['top']
# service
# ['reliable', 'customer', 'on']
# service
# ['great', 'clean', 'accord']
# service
# ['top', 'coffee']
# service
# []
# service
# []
# service
# ['courteous', 'staff', 'great', 'in']
# service
# ['great']
# service
# ['excellent']
# service
# ['great']
# service
# ['perfect', 'time', '😊']
# service
# []
# service
# ['friendly', 'and', 'completion', 'of']
# service
# ['great', 'with']
# service
# ['great', 'and', 'staff']
# service
# ['top', 'and', 'advice', 'from', 'for']
# service
# []
# service
# ['good', 'competent']
# service
# ['great', 'and', 'support', 'as', 'processing']
# service
# ['great']
# service
# ['top']
# service
# ['bad']
# service
# ['good', 'and', 'focus']
# service
# []
# service
# []
# service
# ['great']
# service
# ['satisfied', 'perfect']
# service
# ['good', 'personal']
# service
# ['friendly']
# service
# []
# service
# ['top']
# service
# ['good', 'and', 'advice', 'be']
# service
# ['the', 'be']
# service
# []
# service
# ['dealer', 'always', 'good', 'and', 'car']
# service
# ['top', 'satisfied']
# service
# ['top']
# service
# ['nice']
# service
# ['great']
# service
# ['coolant', 'professional', 'friendly', 'and', 'helpful']
# service
# ['good']
# service
# ['and', 'quality']
# service
# ['this']
# service
# []
# service
# ['fantastic']
# service
# ['great', 'friendly']
# service
# ['fast', 'perfect']
# service
# ['fast', 'perfect']
# service
# ['great']
# service
# ['top', 'and', 'advice']
# service
# ['good']
# service
# ['great']
# service
# ['good']
# service
# ['good']
# service
# ['good', 'and', 'advice']
# service
# ['super', 'shuttle']
# service
# ['friendly']
# service
# ['top']
# service
# ['and', 'processing', 'at']
# service
# ['the', 'good', 'receive']
# service
# ['the', 'due']
# service
# ['the', 'acceptance']
# service
# ['delivery']
# service
# ['partly', 'customer']
# service
# ['such', 'a']
# service
# ['such', 'a', 'be']
# service
# []
# service
# []
# service
# ['the', 'for']
# service
# ['the']
# service
# []
# service
# []
# service
# ['gröbenzell', 'perfect', 'and', 'recommendablep']
# service
# []
# service
# []
# service
# ['all']
# service
# ['good', 'customer', 'with']
# service
# []
# service
# ['the', 'customer']
# service
# ['customer', 'and', 'performance']
# service
# []
# service
# ['the']
# service
# []
# service
# []
# service
# ['delivery']
# service
# ['good', 'and', 'workshop']
# service
# []
# service
# ['hellogreat', 'and', 'response']
# service
# ['good']
# service
# ['the']
# service
# ['the', 'fine', 'be']
# service
# ['year']
# service
# ['top']
# service
# ['top']
# service
# ['great']
# service
# ['good']
# service
# []
# service
# ['such', 'good']
# service
# ['great']
# service
# ['excellent']
# service
# ['beautifulupdate', 'september', 'in', 'by']
# service
# ['colanero', 'pour', 'un', 'en']
# service
# ['the', 'fast']
# service
# ['the', 'complete', 'be']
# service
# ['the']
# service
# ['what']
# service
# ['course', 'workshop']
# service
# ['friendly']
# service
# ['excellent']
# service
# ['super', 'staff', 'car']
# service
# []
# service
# ['top', 'good']
# service
# []
# service
# []
# service
# ['good']
# service
# ['customer']
# service
# ['the']
# service
# ['the', 'major', 'customer']
# service
# ['great', 'and', 'team']
# service
# []
# service
# ['the', 'hol']
# service
# ['friendly', 'competent', 'professional', 'great', 'for']
# service
# ['dealership', 'and', 'sale']
# service
# ['good', 'and', 'advice', 'part']
# service
# []
# service
# []
# service
# ['super']
# service
# ['super', 'friendly']
# service
# ['super', 'advice', 'appointment', 'and', 'call']
# service
# ['dealership', 'great', 'and', 'processing', 'again']
# service
# ['friendly']
# service
# ['top', 'and', 'friendly']
# service
# ['friendly', 'good']
# service
# ['poor', 'parking']
# service
# ['good']
# service
# []
# service
# []
# service
# ['fair', 'pricesgood']
# service
# ['pleasant', 'professional']
# service
# []
# service
# ['no', 'or', 'communication', 'on', 'for', 'go']
# service
# ['audi']
# service
# []
# service
# ['nice', 'new', 'customer', 'in', 'tt', 'in']
# service
# ['the', 'holiday', 'great']
# service
# ['great']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['great', 'advice', 'great', 'and', 'pricesa', 'big']
# service
# ['great']
# service
# ['the', 'friendly', 'on']
# service
# ['the']
# service
# ['great']
# service
# ['it', 'in']
# service
# ['people', 'fast']
# service
# ['configure']
# service
# []
# service
# ['this', 'great', 'customer']
# service
# ['and', 'workshop']
# service
# ['top', 'in']
# service
# []
# service
# ['next', 'and', 'oil']
# service
# []
# service
# ['a', 'problem', 'eithernext', 'here']
# service
# ['the', 'in']
# service
# []
# service
# ['customer']
# service
# ['our']
# service
# []
# service
# []
# service
# ['and', 'contact']
# service
# []
# service
# ['great', 'and', 'supportmany']
# service
# []
# service
# []
# service
# ['the', 'of']
# service
# []
# service
# ['the', 'quick']
# service
# ['great', 'one', 'because', 'without']
# service
# ['super', 'wish', 'for', 'deal']
# service
# ['repair']
# service
# ['good']
# service
# ['the']
# service
# ['good', 'on']
# service
# ['the', 'at']
# service
# ['the', 'friendly', 'from', 'buy']
# service
# ['unanswered', 'customer']
# service
# ['a']
# service
# ['a', 'ihv']
# service
# ['good', 'customer']
# service
# ['the']
# service
# ['customer']
# service
# []
# service
# ['the', 'of']
# service
# ['great']
# service
# []
# service
# ['a', 'in']
# service
# ['a', 'reliable']
# service
# ['customer']
# service
# ['good']
# service
# ['great', 'from']
# service
# ['the', 'great', 'give']
# service
# ['friendly', 'fast', 'by', 'as']
# service
# ['great']
# service
# ['a', 'normal']
# service
# ['the', 'advice', 'and', 'staff']
# service
# ['both', 'the', 'and', 'support']
# service
# ['the']
# service
# []
# service
# ['the', 'dealership', 'great']
# service
# ['customer']
# service
# ['great', 'staff']
# service
# ['great']
# service
# ['great', 'staff', 'fast']
# service
# ['great', 'fast']
# service
# ['the']
# service
# ['good', 'and', 'book', 'space']
# service
# ['great']
# service
# ['in', 'great']
# service
# ['part', 'supplytop']
# service
# ['the']
# service
# ['all', 'nice']
# service
# ['good']
# service
# ['professional']
# service
# ['the', 'good', 'and', 'support']
# service
# []
# service
# ['good', 'accurate']
# service
# ['its', 'stressful', 'the', 'customer']
# service
# ['staff', 'overall', 'good']
# service
# ['friendly', 'staff', 'good']
# service
# []
# service
# []
# service
# ['friendly', 'staff', 'good']
# service
# ['great', 'staff']
# service
# ['great', 'and', 'staff']
# service
# []
# service
# ['good', 'friendly']
# service
# ['good']
# service
# ['good', 'customer', 'with']
# service
# ['top', 'at']
# service
# ['great']
# service
# ['fast']
# service
# ['a', 'great']
# service
# ['great']
# service
# ['good']
# service
# ['good', 'uncomplicated', 'and', 'staff']
# service
# ['competent']
# service
# ['fast']
# service
# ['friendly']
# service
# []
# service
# []
# service
# ['always', 'good']
# service
# ['great']
# service
# ['a', 'great']
# service
# ['good', 'and', 'person']
# service
# []
# service
# ['friendly']
# service
# ['great']
# service
# ['friendly']
# service
# ['good', 'helpfull', 'with']
# service
# ['great']
# service
# ['top', 'from']
# service
# ['poor']
# service
# []
# service
# []
# service
# ['a', 'for', 'by']
# service
# []
# service
# ['many']
# service
# []
# service
# ['advice', 'deal', 'top', 'and', 'this', 'with']
# service
# ['audi', 'customer']
# service
# ['the', 'be']
# service
# ['the']
# service
# []
# service
# ['great', 'all']
# service
# ['absolutely']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'sbahn', 'great', 'gillhuber']
# service
# ['poor', 'for']
# service
# ['competent', 'attentive', 'good', 'and', 'convince', 'of']
# service
# ['themthe', 'last']
# service
# ['customer']
# service
# ['such', 'poor']
# service
# []
# service
# ['excellent', 'and', 'döringer']
# service
# ['these']
# service
# ['the']
# service
# []
# service
# []
# service
# ['the']
# service
# ['the', 'word']
# service
# ['more']
# service
# []
# service
# []
# service
# ['workshop', '👍']
# service
# ['here', 'audi', 'good', 'and', 'deal', 'with', 'from']
# service
# ['the']
# service
# ['a', 'great']
# service
# []
# service
# []
# service
# ['good', 'in', 'big']
# service
# ['the']
# service
# ['customer', 'in']
# service
# ['okay', 'friendly']
# service
# ['courteous', 'quick']
# service
# ['employee', 'an', 'allround', 'satisfaction']
# service
# ['top']
# service
# ['great', 'and', 'staff', 'always']
# service
# ['great', 'and', 'advice']
# service
# ['premium', 'allround']
# service
# ['perfect']
# service
# []
# service
# ['brilliant']
# service
# ['super']
# service
# ['top', 'advice', 'customer']
# service
# ['staff', 'top']
# service
# ['perfect']
# service
# ['all', 'the']
# service
# ['all']
# service
# ['the']
# service
# ['a', 'great']
# service
# ['excellent', 'and', 'staff', 'speak', 'be']
# service
# ['all', 'friendly', 'and', 'department']
# service
# ['personal']
# service
# ['the', 'during']
# service
# ['top', 'staff']
# service
# ['precisely', 'the', 'competent', 'friendly', 'from', 'prompt']
# service
# ['such', 'a']
# service
# ['friendly']
# service
# []
# service
# ['a', 'be']
# service
# ['the', 'negotiate']
# service
# ['the', 'and', 'advice']
# service
# []
# service
# []
# service
# ['landshut', 'customer', 'and', 'agreement']
# service
# ['bad', 'customer']
# service
# ['either', 'the', 'or', 'team']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['your']
# service
# ['good']
# service
# ['customer']
# service
# ['the', 'onsite', 'reach']
# service
# []
# service
# []
# service
# ['the']
# service
# ['audi']
# service
# ['related']
# service
# ['perfect', 'audi', 'and']
# service
# ['unanswered', 'and', 'effort']
# service
# ['the', 'competent']
# service
# ['good']
# service
# []
# service
# []
# service
# []
# service
# ['great', 'supportwe']
# service
# ['friendly', 'here', 'and', 'lot', 'fitsa', '👍', '🏼', '️']
# service
# []
# service
# ['master']
# service
# ['great', 'great', 'customer']
# service
# ['no', 'customer']
# service
# []
# service
# ['a', 'cappuccino', 'for']
# service
# ['the', 'car']
# service
# ['excellent']
# service
# ['the', 'center', 'great', 'and', 'staff']
# service
# ['always', 'good', 'advice']
# service
# []
# service
# ['staff', 'good']
# service
# ['staff', 'good']
# service
# ['the', 'and', 'staff']
# service
# ['top', 'advice', 'good']
# service
# ['good', 'everything', 'to']
# service
# ['good']
# service
# []
# service
# ['professional', 'great']
# service
# ['great']
# service
# ['good']
# service
# ['perfect', 'for', 'friendly']
# service
# []
# service
# ['friendly', 'right']
# service
# ['top']
# service
# ['great']
# service
# ['bad']
# service
# ['good', 'option', 'export']
# service
# ['top']
# service
# ['tyre', 'change', 'tire', 'storage', 'customer', 'etc']
# service
# ['great', 'from']
# service
# ['dealership', 'top', 'customer', 'be', 'and', 'audi']
# service
# ['process', 'good', 'and', 'vehicle']
# service
# ['the']
# service
# ['this', 'excellent', 'customer', 'from', 'honest']
# service
# ['our', 'mindsconclusion', 'great']
# service
# ['the', 'and', 'hermann']
# service
# []
# service
# ['excellent', 'customer', 'and', 'friendly']
# service
# ['the']
# service
# ['absolute', 'top']
# service
# ['such', 'perfect']
# service
# []
# service
# []
# service
# ['company']
# service
# ['the']
# service
# ['good']
# service
# ['great', 'and', 'staffwe']
# service
# []
# service
# ['the', 'reliable', 'superfriendly']
# service
# []
# service
# []
# service
# ['the', 'be']
# service
# ['no', 'well', 'and', 'support']
# service
# ['great', 'and', 'offer']
# service
# ['the', 'great']
# service
# ['mr', 'goldstein', 'great']
# service
# ['the', 'good', 'and', 'advice', 'on']
# service
# []
# service
# ['recommend']
# service
# ['professionally', 'in']
# service
# ['the', 'and', 'advice']
# service
# ['the', 'and', 'advice', 'from']
# service
# ['friendly']
# service
# ['great']
# service
# ['customer']
# service
# ['the', 'customer', 'there']
# service
# ['the', 'telephone', 'register', 'and']
# service
# ['such', 'a', 'wonderful', 'advise']
# service
# ['the']
# service
# ['great']
# service
# ['car', 'great']
# service
# ['hometop', 'customer', 'and', 'car']
# service
# ['customer']
# service
# ['this', 'great']
# service
# []
# service
# ['checkout', 'dealership', 'nice']
# service
# []
# service
# []
# service
# ['great', 'scholz']
# service
# ['withthe', 'and', 'service']
# service
# ['the', 'by']
# service
# ['bad', 'customer', 'call']
# service
# ['perfect']
# service
# ['pleasant', 'customer', 'from']
# service
# ['great', 'courteous']
# service
# []
# service
# ['the', 'great', 'at', 'at']
# service
# []
# service
# ['the']
# service
# []
# service
# ['convinced', 'great', 'courteous', 'salesperson']
# service
# ['good', 'and', 'advice', 'from']
# service
# ['their', 'bjekovic']
# service
# ['hilfsbereitden', 'good', 'from']
# service
# []
# service
# ['car', 'great']
# service
# []
# service
# ['top', 'super', 'fast', 'great']
# service
# []
# service
# ['process', 'outstanding']
# service
# ['the', 'of']
# service
# ['great', 'from']
# service
# ['the', 'in']
# service
# ['mediocre']
# service
# []
# service
# ['customer']
# service
# ['super']
# service
# []
# service
# ['and', 'advice']
# service
# ['super', 'breakdown', 'tire']
# service
# ['great', 'and', 'contact', 'bring']
# service
# []
# service
# ['you', 'super']
# service
# ['super']
# service
# ['competent', 'advice', 'great', 'and', 'atmosphere', 'recommend']
# service
# ['good']
# service
# []
# service
# ['great', 'and', 'advice']
# service
# ['the', 'courteous']
# service
# ['top']
# service
# ['wonderful', 'advice', 'great']
# service
# ['great', '🏻']
# service
# ['seller', 'great']
# service
# ['and', 'inspection']
# service
# []
# service
# ['or', 'deal']
# service
# ['great']
# service
# ['top']
# service
# ['great']
# service
# []
# service
# ['lousy', 'customer', 'bring']
# service
# []
# service
# ['the', 'brand', 'customer']
# service
# ['post']
# service
# ['my', 'car', 'customer']
# service
# ['friendly']
# service
# ['great', 'for', 'and', 'drinkseveryone']
# service
# []
# service
# ['today', 'customer']
# service
# ['excellent', 'customer']
# service
# ['good']
# service
# ['top', 'with']
# service
# ['the']
# service
# []
# service
# ['friendly', 'staff', 'excellent', 'customer', 'in', 'm']
# service
# []
# service
# []
# service
# []
# service
# ['workshop']
# service
# []
# service
# []
# service
# ['a', 'great']
# service
# []
# service
# []
# service
# ['my', 'there', 'great']
# service
# []
# service
# ['good']
# service
# ['super']
# service
# ['traceable', 'hollow', 'delivery']
# service
# ['a', 'nice', 'great', 'friendly', 'from']
# service
# []
# service
# ['the']
# service
# ['such', 'good']
# service
# []
# service
# ['the']
# service
# []
# service
# []
# service
# ['the', 'service', 'customer']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['a', 'customer', 'and', 'or', 'visit']
# service
# ['even', 'further', 'in']
# service
# ['excellent', 'and', 'customer']
# service
# []
# service
# []
# service
# ['friendly', 'young', 'competent']
# service
# ['the']
# service
# []
# service
# ['good']
# service
# ['the', 'for']
# service
# ['the', 'customer']
# service
# ['the', 'great']
# service
# ['good']
# service
# ['customer']
# service
# ['my', 'next', 'customer']
# service
# ['friendly', 'do']
# service
# ['customer']
# service
# ['several', 'timesthe']
# service
# ['correct', 'master']
# service
# []
# service
# ['the', 'with']
# service
# []
# service
# ['great', 'and']
# service
# ['customer']
# service
# ['top', 'and', 'seller']
# service
# []
# service
# []
# service
# ['and', 'maintenance']
# service
# ['good']
# service
# []
# service
# ['audi']
# service
# ['friendly', 'express']
# service
# []
# service
# ['good', 'and', 'staff']
# service
# ['friendly']
# service
# []
# service
# ['service', 'customer']
# service
# ['good']
# service
# []
# service
# ['friendly', 'staffvery', 'advicesuper']
# service
# ['good', 'and', 'advice']
# service
# ['top', 'employee']
# service
# ['the', 'and', 'profit']
# service
# ['again', 'a', 'great', 'like']
# service
# ['great', 'staff']
# service
# []
# service
# ['the']
# service
# ['good', 'serious']
# service
# ['great']
# service
# ['outstanding', 'fast']
# service
# ['quick', 'kind']
# service
# ['friendly']
# service
# ['customer']
# service
# []
# service
# ['nice', 'customer', 'and', 'solution']
# service
# []
# service
# ['top']
# service
# ['professional', 'customer']
# service
# []
# service
# []
# service
# ['good']
# service
# ['mr', 'könig', 'and', 'empathy']
# service
# ['detail', 'great']
# service
# ['so', 'clear', 'recommendation', 'top']
# service
# ['my', 'new', 'customer']
# service
# ['a', 'top', 'for']
# service
# ['the']
# service
# ['his', 'competent', 'customercentric', 'tradein']
# service
# ['our', 'side', 'rating', 'competence']
# service
# ['good']
# service
# ['with', 'in', 'and', 'tint']
# service
# ['and', 'advice', 'value', 'in', 'expensive']
# service
# ['the', 'at']
# service
# ['friendly', 'staff', 'reliable', 'and', 'contact']
# service
# []
# service
# ['reliable', 'fast', 'noteworthy']
# service
# []
# service
# []
# service
# ['bad', 'customer']
# service
# ['week', 'agothe']
# service
# ['repairsas', 'friendly']
# service
# ['great', 'be']
# service
# ['great', 'friendly', 'all']
# service
# []
# service
# ['the', 'order', 'excellent']
# service
# []
# service
# ['the', 'mention']
# service
# ['the']
# service
# ['the', 'and', 'acceptance', 'of']
# service
# ['and', 'interest', 'in', 'much', 'häfnerswitching', 'to']
# service
# ['hybrid', 'disappointing']
# service
# ['it', 'buy']
# service
# ['the', 'departmentthe']
# service
# ['his']
# service
# ['a', 'like']
# service
# ['the', 'allround']
# service
# ['customer']
# service
# ['the']
# service
# ['a', 'special', 'as']
# service
# []
# service
# ['a']
# service
# ['customer']
# service
# ['the', 'beverage']
# service
# ['friendly', 'great']
# service
# []
# service
# ['first', 'class', 'expect']
# service
# []
# service
# ['call']
# service
# []
# service
# ['customer', 'in', 'on']
# service
# []
# service
# ['audi']
# service
# ['the', 'complete']
# service
# []
# service
# ['great', 'from', 'call', 'and']
# service
# ['top']
# service
# ['this', 'miserable']
# service
# ['the', 'deserve']
# service
# ['it', 'etc']
# service
# ['the', 'from']
# service
# []
# service
# ['replacement', 'vehiclethe', 'at']
# service
# ['such', 'attentive', 'customer']
# service
# ['customer']
# service
# ['audi']
# service
# ['great', 'handle']
# service
# ['friendly', 'flexible', 'great', 'be']
# service
# []
# service
# ['the']
# service
# []
# service
# []
# service
# ['from']
# service
# []
# service
# ['great', 'and', 'advice', 'buy']
# service
# ['the', 'of']
# service
# ['the']
# service
# ['good']
# service
# []
# service
# ['great', 'great']
# service
# ['friendly', 'competent', 'staffatmosphere', 'come']
# service
# ['and', 'smile', 'be']
# service
# []
# service
# ['correspond']
# service
# ['any', 'do']
# service
# ['audi', 'top']
# service
# ['customer']
# service
# ['the', 'provide', 'go', 'behavior']
# service
# ['customer']
# service
# ['the', 'good', 'and', 'customer']
# service
# ['the']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'nor', 'problem', 'with']
# service
# ['a', 'top', 'recommend']
# service
# ['super', 'appointment']
# service
# ['poor']
# service
# ['the']
# service
# ['no']
# service
# ['the']
# service
# ['troubleno', 'competent']
# service
# ['super', 'fast', 'acceptance']
# service
# ['the', 'stuttgart', 'great']
# service
# ['the']
# service
# ['top', 'and', 'everything']
# service
# ['the']
# service
# ['good']
# service
# ['the', 'identify']
# service
# ['good']
# service
# ['the', 'competent', 'advisory', 'apoussidis', 'from']
# service
# ['the', 'and', 'performance']
# service
# ['nice']
# service
# ['an', 'appointment']
# service
# ['unreliablecalled', 'and', 'ask']
# service
# []
# service
# ['the', 'branchabsolute', 'top']
# service
# ['every', 'inspection']
# service
# ['this']
# service
# ['the', 'in']
# service
# ['professional', 'factory']
# service
# ['customer']
# service
# ['the', 'competent', 'of']
# service
# ['a', 'great']
# service
# ['bad', 'sale', 'at']
# service
# ['the']
# service
# []
# service
# ['the', 'vehicle', 'super']
# service
# ['the', 'honest']
# service
# []
# service
# ['the', 'poor']
# service
# ['situation']
# service
# []
# service
# ['the', 'of']
# service
# ['great']
# service
# ['the']
# service
# ['the', 'advice', 'and', 'imagination']
# service
# ['great', 'customer']
# service
# ['great']
# service
# ['his', 'and', 'feser']
# service
# ['first', 'class', 'and', 'advice', 'with']
# service
# ['ambience', 'little', 'friendly', 'want']
# service
# ['top', 'and', 'team']
# service
# ['part']
# service
# ['the']
# service
# ['first', 'class']
# service
# ['process']
# service
# ['satisfied', 'attentive', 'and', 'communication']
# service
# ['good']
# service
# []
# service
# []
# service
# ['great', 'and', 'advice', 'from']
# service
# []
# service
# ['staff', 'great', 'in', 'compliment']
# service
# ['the', 'and', 'help']
# service
# ['good', 'and', 'staffi']
# service
# ['excellent']
# service
# ['top']
# service
# []
# service
# []
# service
# []
# service
# ['top', 'from', 'there']
# service
# []
# service
# []
# service
# ['great']
# service
# ['huge', 'vehicle', 'choice']
# service
# ['all', 'fast']
# service
# ['super']
# service
# ['top', 'quick']
# service
# ['good', 'with']
# service
# ['the', 'part']
# service
# []
# service
# ['great']
# service
# ['great']
# service
# ['great']
# service
# ['competent', 'helpful', 'great']
# service
# ['professional', 'in']
# service
# ['staff', 'top']
# service
# ['top', 'by']
# service
# []
# service
# []
# service
# ['great']
# service
# ['good']
# service
# ['always', 'a', 'great']
# service
# []
# service
# ['good']
# service
# ['good']
# service
# []
# service
# ['good']
# service
# ['top']
# service
# ['professional', 'knowledgeable', 'from', 'kind']
# service
# ['customer']
# service
# ['outstanding', 'on']
# service
# []
# service
# ['the', 'great']
# service
# []
# service
# ['top', 'from', 'purchase']
# service
# ['your', 'great']
# service
# []
# service
# ['my']
# service
# ['excellent', 'competent', 'helpful', 'fair']
# service
# ['the', 'good']
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# ['the', 'and', 'repair']
# service
# ['inspectiongreat', 'nice']
# service
# ['the']
# service
# ['and', 'quality']
# service
# ['the', 'extraordinary', 'and', 'care']
# service
# ['such', 'a', 'wish']
# service
# []
# service
# ['the', 'great']
# service
# ['impeccable', 'customer']
# service
# []
# service
# []
# service
# ['courteous', 'customer', 'wish']
# service
# ['great']
# service
# ['dealership', 'great', 'hand']
# service
# ['repair', 'customer']
# service
# []
# service
# ['the']
# service
# ['customer']
# service
# []
# service
# ['the']
# service
# ['delivery']
# service
# []
# service
# []
# service
# ['oil']
# service
# ['the', 'and', 'workshop']
# service
# ['customer']
# service
# ['the', 'bad']
# service
# ['this', 'bad', 'experience']
# service
# []
# service
# ['freethe']
# service
# []
# service
# ['hol', 'bring']
# service
# []
# service
# []
# service
# []
# service
# ['even', 'customer']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['the', 'second', 'see']
# service
# []
# service
# ['conclusion']
# service
# []
# service
# ['porsche']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# ['place', 'customer']
# service
# ['customer']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# []
# service
# ['the', 'customer']
# service
# ['top', 'conditionsthe', 'in']
# service
# ['in']
# service
# ['customer']
# service
# ['the', 'next']
# service
# []
# service
# ['the', 'first']
# service
# ['top']
# service
# ['excellent']
# service
# ['customer']
# service
# ['the']
# service
# []
# service
# ['mr', 'michael', 'greibel']
# service
# ['super', 'be']
# service
# ['the', 'airport', 'call']
# service
# ['this', 'airport']
# service
# ['customer']
# service
# []
# service
# ['part']
# service
# []
# service
# []
# service
# ['the']
# service
# ['of', 'the']
# service
# ['the']
# service
# ['the', 'first', 'everything', 'to']
# service
# []
# service
# ['good', 'and', 'staff']
# service
# ['the']
# service
# ['great']
# service
# ['perfect', 'gross']
# service
# ['the', 'great']
# service
# ['great', 'people']
# service
# ['good']
# service
# []
# service
# ['customer']
# service
# ['staff', 'great']
# service
# ['customer']
# service
# []
# service
# ['prompt', 'by', 'due']
# service
# ['the', 'polite', 'and', 'bernd', 'm']
# service
# []
# service
# ['good']
# service
# ['the']
# service
# ['great', 'and', 'advice']
# service
# []
# service
# []
# service
# []
# service
# ['customer']
# service
# ['great']
# service
# []
# service
# ['and', 'workshop']
# service
# ['good', 'and', 'range']
# service
# ['good', 'and', 'friendly', 'staff']
# service
# ['great', 'and', 'advice']
# service
# ['great']
# service
# ['super', 'dealership', 'top']
# service
# ['super']
# service
# ['great', 'to']
# service
# []
# service
# ['gebel', 'great', 'and', 'advice']
# service
# ['the', 'first']
# service
# []
# service
# ['the', 'purchasevery', 'good', 'customer']
# service
# ['courteous']
# service
# ['such', 'an', 'incompetent', 'customer']
# service
# ['super']
# service
# ['the']
# service
# ['top', 'for']
# service
# ['staff', 'great']
# service
# ['the', 'of']
# service
# ['space', 'friendly']
# service
# ['top', 'processing', 'professional']
# service
# ['top']
# service
# ['great']
# service
# ['top', 'and', 'staff']
# service
# ['good', 'car', 'okay']
# service
# ['top', 'with']
# service
# ['great', 'nice']
# service
# ['fast']
# service
# ['a', 'great']
# service
# ['good']
# service
# ['great', 'and', 'informationmr']
# service
# ['the', 'and']
# service
# ['excellent', 'and', 'nice', 'see']
# service
# ['theregreat']
# service
# []
# service
# ['the', 'and', 'car']
# service
# ['good']
# service
# []
# service
# ['the', 'for']
# service
# ['audi', 'line']
# service
# ['customer']
# service
# ['great', 'customer']
# service
# ['car']
# service
# ['customer']
# service
# ['and']
# service
# ['their']
# service
# ['staff']
# service
# ['great', 'staff']
# service
# ['nice', 'friendly', 'well', 'book']
# service
# ['quick']
# service
# ['great']
# service
# ['top']
# service
# ['excellent']
# service
# ['this', 'firstclass']
# service
# ['the', 'at']
# service
# ['the', 'fast']
# service
# ['workshop']
# service
# ['top']
# service
# ['perfect', 'from', 'lia']
# service
# []
# service
# ['registration', 'after']
# service
# ['super', 'car']
# service
# []
# service
# ['accommodating']
# service
# []
# service
# ['excellent']
# service
# ['great']
# service
# []
# service
# ['top', 'have']
# service
# ['good']
# service
# ['first', 'class', 'day', 'before', 'spontaneously', 'after']
# service
# ['great', 'too', 'customer', 'in']
# service
# ['good', 'for']
# service
# []
# service
# ['another', 'audi']
# service
# []
# service
# ['customer', 'and', 'service', 'at']
# service
# ['tire', 'changethe']
# service
# ['delivery']
# service
# ['customer', 'be']
# service
# ['great', 'and', 'information', 'excellent']
# service
# []
# service
# []
# service
# ['friendly', 'with']
# service
# []
# service
# ['the', 'front', 'desk', 'or', 'salesi']
# service
# []
# service
# []
# service
# ['nice']
# service
# ['customer']
# service
# ['customer']
# service
# ['or', 'sale']
# service
# ['the']
# service
# ['absolutely', 'the', 'good', 'experience', 'recommend']
# service
# []
# service
# ['great']
# service
# ['such', 'a', 'customer']
# service
# ['this']
# service
# ['good']
# service
# []
# service
# ['great']
# service
# ['the', 'great', 'professional', 'be']
# service
# []
# service
# []
# service
# ['competence']
# service
# ['the']
# service
# ['car', 'poor']
# service
# []
# service
# ['the']
# service
# []
# service
# ['the', 'and', 'advice']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'of']
# service
# []
# service
# []
# service
# ['the']
# service
# ['change', 'top']
# service
# ['the', 'iron']
# service
# ['upthe', 'in']
# service
# ['the', 'name', 'customer']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['customer']
# service
# ['the']
# service
# []
# service
# ['the']
# service
# ['the', 'current', 'status', 'customer']
# service
# ['well']
# service
# ['good', 'in', 'change']
# service
# []
# service
# []
# service
# ['super']
# service
# []
# service
# ['the']
# service
# ['the', 'there']
# service
# ['premium', 'like']
# service
# ['the', 'identify']
# service
# ['schedule']
# service
# ['the']
# service
# ['the', 'field', 'of']
# service
# ['the', 'and', 'handling', 'via']
# service
# ['the', 'customervery', 'good', 'and', 'completion', 'of']
# service
# ['good', 'have', 'brückmann']
# service
# ['the', 'chauffeur', 'drive', 'advise']
# service
# ['no']
# service
# ['the', 'in']
# service
# ['super', 'get']
# service
# ['the', 'airport']
# service
# ['the', 'airport']
# service
# ['the', 'airport']
# service
# []
# service
# []
# service
# ['the']
# service
# ['the']
# service
# ['a', 'great']
# service
# ['and', 'repair']
# service
# []
# service
# ['such', 'motivated']
# service
# []
# service
# ['a']
# service
# ['bad']
# service
# []
# service
# ['great']
# service
# ['top']
# service
# ['the', 'good']
# service
# ['super']
# service
# ['the', 'airport', 'and', 'team']
# service
# []
# service
# ['the']
# service
# ['the']
# service
# ['the', 'premium', 'warranty', 'from']
# service
# ['the']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# ['a', 'be']
# service
# ['dreadful']
# service
# ['nice']
# service
# ['dealershipfriendly', 'for']
# service
# ['good']
# service
# ['sale']
# service
# ['super']
# service
# []
# service
# []
# service
# []
# service
# ['the', 'and', 'dealing']
# service
# []
# service
# ['the', 'audi', 'airport']
# service
# ['friendly', 'from']
# service
# ['the', 'firstclass', 'and', 'processing']
# service
# ['friendly', 'from']
# service
# ['and', 'advice']
# service
# ['hose', 'transaction', 'top']
# service
# ['your']
# service
# []
# service
# ['underground', 'have']
# service
# ['such', 'bad']
# service
# ['customer']
# service
# ['great']
# service
# ['customer']
# service
# []
# service
# []
# service
# ['quality', 'top']
# service
# ['good', 'and', 'staff']
# service
# ['from', 'in']
# service
# ['the']
# service
# []
# service
# []
# service
# ['customer']
# service
# ['just', 'right', 'heretop', 'help', 'and', 'above']
# service
# ['bad', 'in']
# service
# ['good']
# service
# ['experience', 'perfect', 'customer']
# service
# ['great', 'need']
# service
# ['good', 'be', 'ideamanuelwalter']
# service
# ['good']
# service
# ['perfect', 'and', 'everyone']
# service
# ['request']
# service
# ['nice', 'courteous', 'helpful', 'advice', 'fast']
# service
# ['first', 'class']
# service
# ['great', 'and', 'greeting']
# service
# ['always', 'good', 'love']
# service
# ['friendly', 'on']
# service
# ['first', 'class', 'greeting', 'noller']
# service
# []
# service
# ['the']
# service
# ['top']
# service
# []
# service
# ['great']
# service
# ['time']
# service
# ['fast', 'in']
# service
# ['great']
# service
# []
# service
# []
# service
# ['friendly', 'again']
# service
# ['nice']
# service
# []
# service
# ['great', 'kevinpfeifer']
# service
# ['and', 'care', 'good']
# service
# ['customer']
# service
# ['advice', 'good']
# service
# ['great', 'from']
# service
# ['top', 'and', 'help', 'manuelwalter']
# service
# []
# service
# ['friendly']
# service
# []
# service
# ['contact']
# service
# ['top']
# service
# ['top', 'customer']
# service
# []
# service
# ['top']
# service
# ['good']
# service
# ['good']
# service
# ['first']
# service
# ['friendly']
# service
# ['professional', 'for', 'winiarek']
# service
# ['good', 'for', 'helpful']
# service
# ['great']
# service
# ['top', '👍']
# service
# ['excellent', 'customeroriented']
# service
# ['the']
# service
# ['major']
# service
# ['the']
# service
# ['the']
# service
# ['the', 'of', 'and']
# service
# []
# service
# ['top']
# service
# ['my', 'car']
# service
# []
# service
# ['another']
# service
# []
# service
# []
# service
# ['the', 'customer']
# service
# ['bmw', 'customer', 'and']
# service
# ['the', 'of']
# service
# ['great', 'and', 'advice', 'from']
# service
# ['job']
# service
# ['the', 'in']
# service
# []
# service
# ['your', 'takecustomer']
# service
# ['super', 'by']
# service
# []
# service
# ['friendly', 'staff']
# service
# []
# service
# []
# service
# ['the', 'large', 'customer', 'be']
# service
# ['single']
# service
# ['the', 'of']
# service
# []
# service
# []
# service
# ['great', 'from']
# service
# ['great', 'friendly', 'here']
# service
# ['all', 'customer']
# service
# []
# service
# []
# service
# ['competent']
# service
# ['what']
# service
# ['excellent', 'be']
# service
# []
# service
# ['bad']
# service
# ['great', 'and', 'advice']
# service
# ['a', 'great']
# service
# ['friendly']
# service
# ['every', 'inspection', 'there']
# service
# []
# service
# ['good', 'and', 'service']
# service
# ['atmosphere', 'customer', 'and', 'service']
# service
# []
# service
# ['great']
# service
# ['excellent', 'and', 'support', 'of', 'by', 'and']
# service
# ['top']
# service
# ['super']
# service
# ['friendly', 'first', 'class']
# service
# ['great']
# service
# ['competent', 'complaint']
# service
# ['outstanding', 'customer']
# service
# ['top', 'staff']
# service
# []
# service
# ['positive']
# service
# ['as']
# service
# []
# service
# ['for', 'part', 'place']
# service
# ['the']
# service
# ['the']
# service
# ['staff', 'solid', 'as', 'speak']
# service
# ['service', 'I', 'car', 'at', 'time', 'and', 'be']
# service
# ['customer']
# service
# []
# service
# ['and', 'inspection']
# service
# ['top']
# service
# ['all', 'top']
# service
# ['great', 'and', 'selection']
# service
# ['great', 'and', 'processing', 'in']
# service
# ['the', 'seller']
# service
# ['great', 'and', 'processing']
# service
# ['and', 'interest', 'in', 'much', 'häfnerswitching', 'to']
# service
# ['top']
# service
# ['this', 'miserable']
# service
# ['the', 'deserve']
# service
# ['a', 'fresh', 'and', 'thing']
# service
# ['the', 'and', 'advice', 'from']
# service
# ['the', 'fantastic']
# service
# ['the', 'firstgreat', 'motivated']
# service
# ['the', 'in']
# service
# ['the', 'last', 'customer']
# service
# ['delivery']
# service
# ['the', 'be']
# service
# ['organize', 'centerthe', 'on']
# service
# ['settlement', 'and', 'handling']
# service
# []
# service
# ['no', 'or', 'inspection']
# service
# ['this', 'customerfriendly']
# service
# ['a', 'great']
# service
# ['and', 'repair']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# ['no']
# service
# []
# service
# ['impeccable', 'staff']
# service
# ['the', 'audi', 'and', 'sale']
# service
# ['great']
# service
# ['good', 'and', 'help']
# service
# ['good', 'be', 'ideamanuelwalter']
# service
# ['friendly', 'switchboard', 'customer']
# service
# ['great', 'and', 'advice', 'from']
# service
# ['top']
# service
# ['professional']
# service
# ['fabiobossertgreat', 'and', 'staff']
# service
# ['great', 'perfect']
# service
# ['top', 'customer']
# service
# []
# service
# ['top']
# service
# ['top', 'always']
# service
# ['good']
# service
# ['audi']
# service
# ['nice']
# service
# ['a', 'competent', 'and', 'repair']
# service
# ['the', 'next']
# service
# ['addendum', 'bad']
# service
# []
# service
# ['the']
# service
# ['the', 'of', 'in']
# service
# ['great']
# service
# ['the', 'great', 'professional', 'be']
# service
# []
# service
# []
# service
# []
# service
# ['good']
# service
# ['at']
# service
# ['good', 'have']
# service
# ['in']
# service
# []
# service
# ['my']
# service
# ['a', 'want']
# service
# []
# service
# []
# service
# ['my']
# service
# []
# service
# ['friendly', 'from']
# ...
# service
# ['a', 'simple', 'with']
# service
# []
# service
# ['the', 'satisfactory', 'customer', 'in']
# service
# ['my', 'purchase', 'sale']
# service
# []
# service
# ['a', 'workshop']
# service
# ['only', 'up', 'last']
# service
# []
# service
# []
# service
# ['mr', 'müller']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['their']
# service
# ['the', 'at']
# service
# ['good', 'customer']
# service
# ['the', 'garage']
# service
# ['and', 'material']
# service
# ['quality']
# service
# []
# service
# ['great', 'in']
# service
# ['top']
# service
# ['car', 'good', 'and', 'friendly']
# service
# ['top', 'and', 'advice', 'on']
# service
# ['a', 'good', 'in']
# service
# []
# service
# ['friendly', 'super', 'be']
# service
# ['good']
# service
# ['courteous', 'no', 'telephone', 'customer']
# service
# []
# service
# ['recommendable', 'top', 'and', 'advice', 's']
# service
# ['the']
# service
# ['quality']
# service
# ['good', 'and', 'dialogue']
# service
# ['selection']
# service
# ['good', 'but', 'expensive']
# service
# ['friendly', 'staff', 'great']
# service
# ['top', 'by']
# service
# ['nice']
# service
# ['good', 'customer']
# service
# ['bad']
# service
# ['bad']
# service
# ['top']
# service
# ['the']
# service
# ['advice', 'top']
# service
# ['everyonesuper']
# service
# ['top']
# service
# ['the']
# service
# ['customer']
# service
# ['delivery']
# service
# ['good']
# service
# []
# service
# ['excellent', 'and']
# service
# ['great']
# service
# ['their', 'own', 'top']
# service
# ['even', 'experiencethumb', 'up', 'urim']
# service
# ['a', 'great', 'order']
# service
# []
# service
# ['great']
# service
# []
# service
# []
# service
# []
# service
# ['dealership', 'top', 'm', 'accept']
# service
# ['the']
# service
# []
# service
# ['the', 'perfect', 'on']
# service
# []
# service
# []
# service
# ['your']
# service
# ['our']
# service
# ['the', 'same', 'top', 'punctual', 'to']
# service
# []
# service
# ['appointment']
# service
# []
# service
# ['the']
# service
# ['the']
# service
# ['the']
# service
# ['the', 'be']
# service
# ['bad']
# service
# ['customer']
# service
# ['great', 'feel']
# service
# ['good']
# service
# ['staff', 'good']
# service
# ['the', 'customer', 'in', 'therefore', 'stand']
# service
# ['to']
# service
# ['good', 'nice', 'staff']
# service
# ['the']
# service
# ['always', 'great', 'personal', 'and', 'communication', 'chatterjee']
# service
# ['and', 'sale']
# service
# ['nice']
# service
# ['with']
# service
# ['advice', 'friendly']
# service
# []
# service
# ['great', 'staff']
# service
# ['both', 'the', 'and', 'organization']
# service
# ['great']
# service
# ['great']
# service
# []
# service
# ['top']
# service
# ['fast']
# service
# []
# service
# ['great']
# service
# ['great']
# service
# ['super']
# service
# ['good', 'and', 'advice']
# service
# ['customer']
# service
# ['good']
# service
# []
# service
# ['class']
# service
# []
# service
# ['the', 'friendly']
# service
# ['great', 'and', 'staff']
# service
# ['great']
# service
# ['friendly', 'nice']
# service
# ['friendly', 'top']
# service
# ['customer']
# service
# ['great']
# service
# []
# service
# ['good', 'and', 'advice']
# service
# ['great', 'and', 'advice']
# service
# ['terrible']
# service
# ['automatik']
# service
# []
# service
# ['fantastic']
# service
# ['perfect']
# service
# []
# service
# ['customer']
# service
# []
# service
# ['the', 'car']
# service
# ['good', 'from']
# service
# ['to', 'advice']
# service
# ['audi']
# service
# ['great', 'advicegreat']
# service
# ['super', 'and', 'quality', 're']
# service
# []
# service
# ['a', 'few', 'question', 'customer']
# service
# ['the', 'good', 'possible', 'm', 'finish']
# service
# []
# service
# []
# service
# ['the', 'and', 'appreciation', 'from']
# service
# []
# service
# ['excellent', 'customer']
# service
# ['great', 'customer', 'despite']
# service
# ['customer']
# service
# ['customer']
# service
# ['great', 'atmosphere', 'again']
# service
# ['this', 'dealershipgreat']
# service
# ['a', 'euro']
# service
# []
# service
# ['speakthe']
# service
# ['the']
# service
# []
# service
# ['immediately', 'nice']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['any', 'decencyconclusion', 'bad']
# service
# []
# service
# []
# service
# ['the']
# service
# ['the', 'teameverywhere']
# service
# []
# service
# ['competent', 'advice', 'great']
# service
# ['and', 'communication']
# service
# ['the']
# service
# ['the', 'in']
# service
# ['fast']
# service
# []
# service
# ['management']
# service
# ['impeccable', 'handle']
# service
# ['good', 'top', 'in']
# service
# ['sale']
# service
# ['great', 'nice']
# service
# []
# service
# ['the', 'recommend']
# service
# ['great', 'and']
# service
# ['acceptance', 'and']
# service
# []
# service
# ['super', 'opt', 'drive']
# service
# ['mobilegreat']
# service
# ['super', 'from', 'uncomplicated', 'solution']
# service
# []
# service
# ['the', 'customer']
# service
# ['customer']
# service
# ['good']
# service
# []
# service
# ['the', 'competent', 'management']
# service
# ['this', 'dealershipgreat']
# service
# ['to']
# service
# []
# service
# []
# service
# ['as']
# service
# []
# service
# ['staff', 'good', 'run']
# service
# ['good', 'from', 'and', 'employee']
# service
# ['a', 'good']
# service
# ['under']
# service
# ['friendly', 'team']
# service
# []
# service
# ['elegant', 'furnishing', 'top']
# service
# ['top', 'and', 'friendly']
# service
# ['the']
# service
# ['competent', 'fast', 'polite']
# service
# []
# service
# ['great', 'customer', 'friendly', '👍']
# service
# ['friendly', 'great']
# service
# ['good', 'and', 'performance']
# service
# []
# service
# ['weak']
# service
# ['top']
# service
# ['the', 'great']
# service
# ['and', 'workshop']
# service
# ['the', 'good', 'on']
# service
# ['my', 'touran']
# service
# []
# service
# ['the']
# service
# ['guarantee']
# service
# ['customer']
# service
# ['the', 'customer']
# service
# ['a', 'nearby', 'customer', 'have']
# service
# ['customer']
# service
# ['great', 'from', 'in']
# service
# ['competitor', 'driving']
# service
# ['due']
# service
# []
# service
# ['excellent']
# service
# ['marieneberg', 'customer']
# service
# ['customer']
# service
# ['reception', 'perfect']
# service
# ['and', 'oil']
# service
# ['and', 'oil']
# service
# ['and', 'oil']
# service
# ['bad']
# service
# []
# service
# ['the']
# service
# ['thrill', 'insanity']
# service
# ['pickup', 'and', 'wash']
# service
# []
# service
# ['lousy', 'staff']
# service
# ['no', 'customer']
# service
# ['great']
# service
# []
# service
# ['top', 'expect']
# service
# []
# service
# []
# service
# ['class']
# service
# ['top']
# service
# ['house', 'good']
# service
# ['great']
# service
# ['first']
# service
# ['top']
# service
# ['top']
# service
# []
# service
# ['bad', 'and', 'part']
# service
# []
# service
# ['its', 'the', 'other', 'departmentlazy', 'customer']
# service
# ['this', 'exceptional', 'and', 'regard']
# service
# []
# service
# ['the', 'and', 'performancei']
# service
# ['what', 'a', 'great']
# service
# ['the', 'skoda', 'mobility', 'car']
# service
# ['the', 'skoda']
# service
# ['the', 'unsatisfactory']
# service
# ['ünal', 'good', 'from']
# service
# ['describe', 'and', 'tüv']
# service
# ['customer']
# service
# ['the']
# service
# ['the']
# service
# []
# service
# ['the', 'great']
# service
# ['the', 'promise']
# service
# ['and', 'inspection']
# service
# []
# service
# ['a', 'free', 'for']
# service
# ['and', 'advice']
# service
# ['especially', 'the', 'customer']
# service
# ['bad']
# service
# []
# service
# ['impeccable', 'after', 'receive']
# service
# []
# service
# []
# service
# []
# service
# ['the']
# service
# ['the']
# service
# ['such', 'good']
# service
# ['the']
# service
# []
# service
# ['great']
# service
# ['customer', 'or', 'interest', 'in']
# service
# ['super', 'customer', 'friendly', 'whether']
# service
# ['good']
# service
# ['and', 'loyalty']
# service
# ['the', 'around']
# service
# []
# service
# ['good', 'workshop', 'good']
# service
# ['cihan', 'ünal', 'the', 'around']
# service
# []
# service
# ['good', 'allround']
# service
# []
# service
# ['good']
# service
# ['my', 'car', 'here', 'for', 'first']
# service
# ['any', 'for']
# service
# ['allround']
# service
# ['the', 'interval']
# service
# ['great']
# service
# ['to', 'with', 'ago']
# service
# ['workshop']
# service
# []
# service
# []
# service
# ['a', 'catastrophic', 'on']
# service
# []
# service
# ['the', 'be', 'wiest', 'and', 'car']
# service
# []
# service
# ['underground', 'customer']
# service
# []
# service
# ['his', 'good']
# service
# ['car', 'super']
# service
# []
# service
# ['super']
# service
# ['great', 'at']
# service
# []
# service
# ['overburdened', 'bosch', 'and', 'professional']
# service
# ['customer']
# service
# ['mr', 'riensuper']
# service
# ['incredible']
# service
# ['the', 'relaxed']
# service
# ['good', 'and', 'staff']
# service
# ['great', 'and', 'atmosphere']
# service
# ['fast']
# service
# ['the', 'right', 'be']
# service
# ['acceptance']
# service
# ['a', 'dealership', 'and', 'competence']
# service
# ['an', 'appointment', 'fast', 'for', 'in']
# service
# ['perfect']
# service
# ['advice', 'great']
# service
# ['poor', 'staff', 'long', 'customer']
# service
# ['good', 'uncomplicated', 'fast', 'great', 'and', 'thank']
# service
# ['friendly', 'staff', 'great', 'in']
# service
# []
# service
# ['great', 'from', 'and', 'röhl']
# service
# ['sale']
# service
# ['great']
# service
# ['good', 'and', 'staff']
# service
# ['great']
# service
# ['great', 'from', 'happy']
# service
# ['a', 'great']
# service
# ['as']
# service
# ['great', 'from', 'and', 'röhl']
# service
# ['badest', 'm']
# service
# ['all', 'the', 'audi']
# service
# ['in']
# service
# ['top']
# service
# ['the']
# service
# []
# service
# ['nice', 'courteous']
# service
# ['great', 'from']
# service
# ['the', 'key', 'great']
# service
# ['top']
# service
# []
# service
# []
# service
# ['dedicated', 'from', 'in', 'locate']
# service
# ['good']
# service
# ['top', 'from']
# service
# ['superfriendly']
# service
# ['service', 'class']
# service
# ['top', 'advice', 'customer', 'as', 'paint']
# service
# []
# service
# ['enterprisegreat']
# service
# ['great']
# service
# ['nice', 'unfortunately', 'in', 'competent']
# service
# ['good']
# service
# ['great', 'from']
# service
# ['bad']
# service
# ['friendly']
# service
# ['top', 'in']
# service
# ['top', 'from']
# service
# ['the']
# service
# ['great', 'from']
# service
# ['good', 'and', 'service']
# service
# ['customer']
# service
# ['great', 'from']
# service
# ['great', 'from']
# service
# ['great']
# service
# ['great', 'from', 'and', 'amir']
# service
# ['great', 'easy']
# service
# ['nice', 'employee', 'great']
# service
# ['professional']
# service
# ['good']
# service
# ['expensive']
# service
# []
# service
# ['perfect', 'allround']
# service
# ['the']
# service
# ['bad', 'have']
# service
# []
# service
# ['good', 'and', 'staff']
# service
# ['great', 'friendly']
# service
# ['good']
# service
# ['good']
# service
# []
# service
# ['friendly']
# service
# ['good']
# service
# ['good', 'and', '🏻']
# service
# ['great']
# service
# ['great', 'give']
# service
# ['customer']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['great', 'and', 'employee', 'appointment', 'time']
# service
# ['this', 'premium']
# service
# ['and', 'repair']
# service
# ['friendly', 'employee', 'reliable', 'and', 'team']
# service
# ['top', 'everything', 'from', 'come']
# service
# []
# service
# ['the']
# service
# []
# service
# ['desiredsuper']
# service
# ['the']
# service
# ['great']
# service
# []
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# ['more', 'be']
# service
# ['first']
# service
# ['a']
# service
# ['the', 'customer', 'itself']
# service
# ['my', 'next', 'customer']
# service
# ['such', 'a', 'be']
# service
# ['such', 'a', 'from', 'bring']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['good', 'and', 'advice', 'from', 'be']
# service
# []
# service
# ['a', 'super']
# service
# ['satisfied', 'great', 'and', 'advice']
# service
# ['good']
# service
# ['bad']
# service
# ['the', 'and', 'support']
# service
# []
# service
# ['bad']
# service
# []
# service
# []
# service
# ['customer']
# service
# ['the', 'and', 'damage']
# service
# ['the', 'customer']
# service
# ['customer']
# service
# ['a', 'charge']
# service
# ['the']
# service
# []
# service
# ['mr', 'shirinov']
# service
# ['perfect', 'customerfriendly', 'up']
# service
# ['great', 'from']
# service
# []
# service
# ['the', 'great']
# service
# []
# service
# ['super', 'fast', 'competent', 'perfect']
# service
# ['reception', 'lady']
# service
# ['good']
# service
# ['top', 'part']
# service
# []
# service
# []
# service
# ['great']
# service
# ['friendly', 'good']
# service
# ['great']
# service
# ['good']
# service
# ['friendly']
# service
# []
# service
# ['his']
# service
# ['the']
# service
# ['friendly']
# service
# ['my', 'complete', 'satisfaction', 'top']
# service
# ['chemnitzexcellent']
# service
# ['the', 'customer', 'and', 'performance']
# service
# []
# service
# []
# service
# ['good']
# service
# ['the']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['audi', 'great', 'and', 'staff']
# service
# ['customer']
# service
# []
# service
# ['friendly', 'and', 'advice']
# service
# []
# service
# ['the']
# service
# []
# service
# ['nice', 'up']
# service
# ['service', 'always', 'top', 'with']
# service
# ['the']
# service
# ['receptiongreat']
# service
# ['nice', 'service', 'great', 'feel', 'round']
# service
# []
# service
# []
# service
# ['workshop', 'great', 'and', 'employee']
# service
# []
# service
# []
# service
# ['the']
# service
# ['center', 'great']
# service
# ['the', 'terrific']
# service
# ['this', 'great']
# service
# ['the', 'good']
# service
# []
# service
# []
# service
# ['super', 'and', 'lead', 'buy']
# service
# ['the']
# service
# ['top']
# service
# ['the']
# service
# ['the', 'reception', 'and', 'sale']
# service
# ['customer']
# service
# []
# service
# ['the', 'procedure', 'shuttle']
# service
# []
# service
# []
# service
# ['great']
# service
# ['good', 'seller']
# service
# []
# service
# []
# service
# ['great', 'on', 'proper']
# service
# ['a', 'good', 'customerfriendly']
# service
# ['great']
# service
# []
# service
# []
# service
# []
# service
# ['a']
# service
# ['advice', 'good', 'but', 'have']
# service
# ['good']
# service
# ['good', 'and', 'advice']
# service
# ['top']
# service
# ['good']
# service
# ['super', 'and', 'competence', 'in']
# service
# ['great']
# service
# ['the', 'part']
# service
# ['super', 'and', 'advice']
# service
# ['top', 'and', 'advice']
# service
# ['a', 'top']
# service
# ['friendly', 'of']
# service
# ['top', 'in']
# service
# ['top', 'and', 'staff', '👍', '🏼']
# service
# ['good']
# service
# ['good']
# service
# ['great']
# service
# ['top']
# service
# ['top']
# service
# ['which']
# service
# ['great']
# service
# []
# service
# []
# service
# ['these']
# service
# ['the', 'courteous', 'customer']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['great']
# service
# ['our', 'seller', 'excellent']
# service
# ['the', 'fast', 'of', 'in']
# service
# []
# service
# ['great', 'sale']
# service
# ['excellent']
# service
# ['sale', 'or', 'maintenance']
# service
# ['the', 'of']
# service
# ['good']
# service
# []
# service
# ['mr', 'farsbotterexcellent']
# service
# ['the', 'onsite']
# service
# []
# service
# ['customer']
# service
# []
# service
# ['this']
# service
# ['the', 'inhouse', 'towing', 'arrive']
# service
# []
# service
# ['the']
# service
# ['and']
# service
# []
# service
# []
# service
# ['the', 'and', 'girl']
# service
# ['the']
# service
# []
# service
# ['offer', 'great']
# service
# ['consultant', 'super']
# service
# ['satisfied', 'the', 'good', 'from']
# service
# ['a', 'competent', 'customeroriented', 'with', 'find']
# service
# []
# service
# ['solvedreception']
# service
# ['the', 'good', 'imagine']
# service
# ['the', 'and']
# service
# []
# service
# ['an', 'oil']
# service
# ['audi']
# service
# ['fes']
# service
# []
# service
# []
# service
# ['good']
# service
# []
# service
# ['the']
# service
# ['the', 'of']
# service
# ['workshop', 'and', 'sale']
# service
# ['the', 'friendly', 'boy']
# service
# []
# service
# ['great', 'and']
# service
# []
# service
# ['processedsuper']
# service
# ['the', 'good', 'have']
# service
# []
# service
# []
# service
# []
# service
# []
# service
# []
# service
# ['good', 'buy', 'weaver']
# service
# ['fast', 'onsite']
# service
# ['great']
# service
# []
# service
# []
# service
# ['good']
# service
# []
# service
# []
# service
# ['great']
# service
# ['bad']
# service
# ['several']
# service
# ['good']
# service
# ['top']
# service
# []
# service
# ['a', 'free', 'shuttle', 'there', 'and']
# service
# []
# service
# ['the', 'process', 'and', 'advice', 'from']
# service
# ['himgreat']
# service
# ['the']
# service
# []
# service
# ['great']
# service
# ['good']
# service
# ['the', 'shuttle']
# service
# ['delivery']
# service
# ['a', 'great']
# service
# ['top', 'competent']
# service
# ['the', 'major']
# service
# ['aftersale']
# service
# ['the']
# service
# ['the', 'good']
# service
# ['nice']
# service
# []
# service
# ['the', 'shuttle', 'as', 'offer']
# service
# []
# service
# ['good', 'customeroriented']
# service
# ['customer']
# service
# ['the', 'part']
# service
# []
# service
# ['simply', 'a', 'bad', 'customer']
# service
# ['satisfied', 'super']
# service
# []
# service
# []
# service
# []
# service
# ['and', 'aboveaverage']
# service
# []
# service
# ['good']
# service
# []
# service
# ['good']
# service
# ['the', 'and', 'advice']
# service
# ['great']
# service
# ['great']
# service
# ['friendly', 'prompt', 'spontaneous', 'for']
# service
# ['good']
# service
# ['great', 'and', 'staff']
# service
# []
# service
# ['top', 'and']
# service
# ['great', 'but', 'overprice']
# service
# ['great', 'and', 'team']
# service
# ['good']
# service
# ['good']
# service
# ['great']
# service
# ['great']
# service
# ['good', 'friendly']
# service
# ['fast', 'in']
# service
# ['perfect']
# service
# ['top']
# service
# ['top', 'good']
# service
# ['great']
# service
# ['good', '👍']
# service
# ['good', 'customer']
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 6514    None
# 6515    None
# 6516    None
# 6517    None
# 6518    None
# Name: lemma_eng_review, Length: 6519, dtype: object
